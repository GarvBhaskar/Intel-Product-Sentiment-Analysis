# %% [markdown]
# ### PS-11 Intel Products Sentiment Analysis from Online Reviews
#
# ##### Team Name: Fractals
# ##### Members: Aviral Srivastava, Garv Bhaskar, Dinesh Kumar
# ##### Institution: Vellore Institute of Technology, Chennai

# %% [markdown]
# ### Table of Contents
# * #### [Part 1. Data Exploration](#part1)
# * #### [Part 2. Data Preparation](#part2)
# * #### [Part 3. Bag of Words](#part3)
# * #### [Part 4. Word2Vec](#part4)
# * #### [Part 5. LSTM](#part5)
# * #### [Part 6. Word Cloud](#part6)
# * #### [Part 7. Summary Generation](#part7)
# * #### [Part 8. Predictions](#part8)

# %%
import os

amazon_dir = './amazon'
os.chdir(amazon_dir)

# %%
# !scrapy crawl amaze
#Will take time to run and make the dataset data.csv

# %%
os.chdir('..')

# %% [markdown]
# ---
# <a id="part1"></a>
# ## Part 1. Data Exploration

# %%
import pandas as pd
import numpy as np
from collections import Counter


import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from wordcloud import WordCloud

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.pipeline import Pipeline

from bs4 import BeautifulSoup  
import re
import nltk
from nltk.corpus import stopwords 
from nltk.stem.porter import PorterStemmer
from nltk.stem import SnowballStemmer, WordNetLemmatizer
from nltk import sent_tokenize, word_tokenize, pos_tag
from nltk.tokenize import PunktSentenceTokenizer  

import logging
import langdetect

from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Lambda, Embedding, LSTM, SimpleRNN, GRU
from tensorflow.keras.preprocessing.text import Tokenizer
from collections import defaultdict
from tensorflow.keras.layers import Conv1D  # Use Conv1D instead of Convolution1D
from tensorflow.keras import backend as K
from keras.utils import to_categorical
from tensorflow import keras
from keras import regularizers

from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
# Out:
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\2790854797.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Load Data

# %%
# Load csv file
df = pd.read_csv('./amazon/data.csv')
df.head(4)
# Out:
#   Intel Core i9 (12th Gen) i9-12900F Hexadeca-core (16 Core) 2.40 GHz Processor - Retail Pack  \
# 0  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 1  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 2  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 3  Intel Core i7-13700K Desktop Processor 16 core...
#
#    Unnamed: 1  5.0 Reviewed in the United States on 17 September 2023  \
# 0         NaN  5.0  Reviewed in the United States on 27 September ...
# 1         NaN  5.0  Reviewed in the United States on 17 September ...
# 2         NaN  5.0  Reviewed in the United States on 27 September ...
# 3         NaN  5.0              Reviewed in India on 3 September 2023
#
#                                         Omar Mendoza  \
# 0                                         F. Machado
# 1                                       Omar Mendoza
# 2                                         F. Machado
# 3  This processor is absolutely incredible with n...
#
#                                                Fast.
# 0  Fast CPU and since I did not need the graphics...
# 1                                              Fast.
# 2  Fast CPU and since I did not need the graphics...
# 3  This processor is absolutely incredible with n...

# %%
df = df.drop(columns=["Unnamed: 1"])
df.head()
# Out:
#   Intel Core i9 (12th Gen) i9-12900F Hexadeca-core (16 Core) 2.40 GHz Processor - Retail Pack  \
# 0  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 1  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 2  Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...
# 3  Intel Core i7-13700K Desktop Processor 16 core...
# 4  Intel Core i7-13700K Desktop Processor 16 core...
#
#    5.0 Reviewed in the United States on 17 September 2023  \
# 0  5.0  Reviewed in the United States on 27 September ...
# 1  5.0  Reviewed in the United States on 17 September ...
# 2  5.0  Reviewed in the United States on 27 September ...
# 3  5.0              Reviewed in India on 3 September 2023
# 4  5.0                 Reviewed in India on 28 March 2023
#
#                                         Omar Mendoza  \
# 0                                         F. Machado
# 1                                       Omar Mendoza
# 2                                         F. Machado
# 3  This processor is absolutely incredible with n...
# 4                                       yogesh Kumar
#
#                                                Fast.
# 0  Fast CPU and since I did not need the graphics...
# 1                                              Fast.
# 2  Fast CPU and since I did not need the graphics...
# 3  This processor is absolutely incredible with n...
# 4  Most powerful cpu at this price bracket no dou...

# %%
df.columns = ["Product", "Rating", "Demographic", "Reviewer", "Comments"]
df
# Out:
#                                                   Product  Rating  \
# 0       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 1       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 2       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 3       Intel Core i7-13700K Desktop Processor 16 core...     5.0
# 4       Intel Core i7-13700K Desktop Processor 16 core...     5.0
# ...                                                   ...     ...
# 110996                      Intel Bx80673I97940X CPU Grey     1.0
# 110997                      Intel Bx80673I97940X CPU Grey     5.0
# 110998                      Intel Bx80673I97940X CPU Grey     5.0
# 110999                      Intel Bx80673I97940X CPU Grey     5.0
# 111000                      Intel Bx80673I97940X CPU Grey     5.0
#
#                                               Demographic  \
# 0       Reviewed in the United States on 27 September ...
# 1       Reviewed in the United States on 17 September ...
# 2       Reviewed in the United States on 27 September ...
# 3                   Reviewed in India on 3 September 2023
# 4                      Reviewed in India on 28 March 2023
# ...                                                   ...
# 110996                  Reviewed in India on 17 June 2020
# 110997              Reviewed in Italy on 19 November 2018
# 110998                 Reviewed in Germany on 2 July 2018
# 110999                   Reviewed in Spain on 20 May 2019
# 111000                  Reviewed in Germany on 8 May 2018
#
#                                                  Reviewer  \
# 0                                              F. Machado
# 1                                            Omar Mendoza
# 2                                              F. Machado
# 3       This processor is absolutely incredible with n...
# 4                                            yogesh Kumar
# ...                                                   ...
# 110996                                    Santhosh Philip
# 110997                                     Cliente Amazon
# 110998                                            Henning
# 110999                                          Latinmau
# 111000                               Mag Guenther Hofmann
#
#                                                  Comments
# 0       Fast CPU and since I did not need the graphics...
# 1                                                   Fast.
# 2       Fast CPU and since I did not need the graphics...
# 3       This processor is absolutely incredible with n...
# 4       Most powerful cpu at this price bracket no dou...
# ...                                                   ...
# 110996                        Not at all working fake one
# 110997                            Un mostro di processore
# 110998  Zum Schneiden und Bearbeiten bestens geeignet....
# 110999  Puro poder de procesador. Honestamente para lo...
# 111000  Für Videoschnitt in Verbindung mit Wasserkühlu...
#
# [111001 rows x 5 columns]

# %%
df[['Location', 'Date']] = df['Demographic'].str.extract(r'Reviewed in (.*?) on (.*)')

df = df.drop(columns=["Demographic", "Reviewer"])

df.columns = ["Product", "Rating", "Reviews", "Location", "Date"]
df
# Out:
#                                                   Product  Rating  \
# 0       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 1       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 2       Intel Core i9 (12th Gen) i9-12900F Hexadeca-co...     5.0
# 3       Intel Core i7-13700K Desktop Processor 16 core...     5.0
# 4       Intel Core i7-13700K Desktop Processor 16 core...     5.0
# ...                                                   ...     ...
# 110996                      Intel Bx80673I97940X CPU Grey     1.0
# 110997                      Intel Bx80673I97940X CPU Grey     5.0
# 110998                      Intel Bx80673I97940X CPU Grey     5.0
# 110999                      Intel Bx80673I97940X CPU Grey     5.0
# 111000                      Intel Bx80673I97940X CPU Grey     5.0
#
#                                                   Reviews           Location  \
# 0       Fast CPU and since I did not need the graphics...  the United States
# 1                                                   Fast.  the United States
# 2       Fast CPU and since I did not need the graphics...  the United States
# 3       This processor is absolutely incredible with n...              India
# 4       Most powerful cpu at this price bracket no dou...              India
# ...                                                   ...                ...
# 110996                        Not at all working fake one              India
# 110997                            Un mostro di processore              Italy
# 110998  Zum Schneiden und Bearbeiten bestens geeignet....            Germany
# 110999  Puro poder de procesador. Honestamente para lo...              Spain
# 111000  Für Videoschnitt in Verbindung mit Wasserkühlu...            Germany
#
#                      Date
# 0       27 September 2022
# 1       17 September 2023
# 2       27 September 2022
# 3        3 September 2023
# 4           28 March 2023
# ...                   ...
# 110996       17 June 2020
# 110997   19 November 2018
# 110998        2 July 2018
# 110999        20 May 2019
# 111000         8 May 2018
#
# [111001 rows x 5 columns]

# %%
distinct_values = df["Product"].unique()

print("Distinct values in Column1:")
for value in distinct_values:
    print(value)
# Out:
# Distinct values in Column1:
# Intel Core i9 (12th Gen) i9-12900F Hexadeca-core (16 Core) 2.40 GHz Processor - Retail Pack
# Intel Core i7-13700K Desktop Processor 16 cores (8 P-cores + 8 E-cores) 30M Cache, up to 5.4 GHz Socket LGA 1700
# Intel Core i7 (12th Gen) i7-12700 Dodeca-core (12 Core) 2.10 GHz Processor - Retail Pack
# Intel Core i9-13900K Desktop Processor LGA 1700 24 cores (8 P-cores + 16 E-cores) 36M Cache, up to 5.8 GHz'
# Intel Core i7-13700KF Gaming Desktop Processor 16 cores (8 P-cores + 8 E-cores) - Unlocked
# Intel® Core™ i9-13900KS Processor 36M Cache, up to 6.00 GHz
# Intel® Core™ i9-14900KS Desktop Processor 24 cores (8 P-cores + 16 E-cores)
# Intel CM8070104291318 Core I3-10100f 3.6ghz Lga1200 Chip Tray Cpu Mm 999wpa
# Intel Core i9-12900K Desktop Processor16 (8P+8E) Cores up to 5.2 GHz Unlocked LGA1700 600 Series Chipset 125W
# Intel Core i7 12700F 12 Gen Desktop PC Processor 12 Core CPU with 25MB Cache and up to 4.9 GHz Clock Speed LGA 1700 4K (Graphic Card Required)
# Intel Core I5 12400F 12 Gen Generation Desktop Pc Processor 6, CPU with 18Mb Cache and Up to 4.40 Ghz Clock Speed Ddr5 and Ddr4 Ram Support Lga 1700 Socket, Micro ATX
# Intel Core i5-13600K Desktop Processor 14 cores (6 P-cores + 8 E-cores) 24M Cache, up to 5.1 GHz' Socket LGA 1700
# Intel Core i5 (12th Gen) i5-12500 3 GHz Processor - Retail Pack
# HP Laptop 14, 13th Gen Intel Core i3-1315U, 14-inch (35.6 cm), FHD, 8GB DDR4, 512GB SSD, Intel UHD Graphics, FHD Camera w/Privacy Shutter, Thin & Light (Win 11, MSO 2021, Blue, 1.4 kg), gr0000TU
# Intel® Core i3-12100 Processor 12M Cache, up to 4.30 GHz LGA1700 Socket
# ZEBRONICS PRO Series Z NBC 5S, Intel Core 12th Gen i7 Processor 16GB RAM & 1TB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Midnight Blue, 1.76 Kg
# Intel Core i3 12100F 12th Gen Generation Desktop PC Processor 4 CPU with 12MB Cache and up to 4.30 GHz Clock Speed LGA 1700 Socket
# Acer Extensa 15 Laptop Intel Core i3 N305 8 core Processor (8 GB/256 GB SSD/Win11 Home/MS Office Home and Student/Intel UHD Graphics/1.7 KG/Silver) EX215-33 FHD Display
# Intel RealSense D455 Depth Camera with IMU (USB Type-C Port) - 82635DSD455
# Lenovo IdeaPad Slim 3 12th Gen Intel Core i3 15.6" (39.6cm) FHD 250 Nits Thin and Light Laptop (8GB/256GB SSD/Windows 11/Office 2021/Alexa/1 Yr ADP Free/3 Month Game Pass/Grey/1.6Kg), 82RK00XDIN
# HP 240 G8 (8J0S2PA) (Intel Core I5 11th Gen / 8GB RAM/ 512GB SSD/DOS/Intel Graphics/ 14 Inch/ 1 Year Warranty) Black
# ASUS Vivobook 15, Intel Core i3-1220P 12th Gen, 15.6" (39.62 cm) FHD, Thin and Laptop (8GB/512GB SSD/Integrated Graphics/Windows 11/Office 2021/Alexa Built-in/FP Sensor/Blue/1.7 kg), X1502ZA-EJ381WS
# Acer Extensa 15 Intel Core i3 N305 8 core Processor (8 GB/512 GB SSD/Win11 Home/MS Office Home and Student/Intel UHD Graphics/1.7 KG/Silver) EX215-33 FHD Display Laptop
# ZEBRONICS PRO Series Z NBC 3S, Intel Core 12th Gen i3 Processor 8GB RAM & 512GB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Space Grey, 1.76 Kg
# HP Laptop 15,12th Gen Intel Core i3-1215U,15.6 inch(39.6 cm),FHD,Anti-Glare,8 GB DDR4,512 GB SSD,Windows 11,MSO,Dual Speakers,1.69 kg,Natural Silver,15s-fq5326TU
# HP All-in-One PC Intel Pentium J5040 21.5-inch(54.6 cm) FHD Three-Sided Micro-Edge Display(8GB RAM/512GB SSD/Intel UHD Graphics/Win 11 Home/Wired Keyboard and Mouse Combo/MS Office)22-dd2686in, White
# ZEBRONICS PRO Series Z NBC 3S, Intel Core 12th Gen i3 Processor 8GB RAM & 512GB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Midnight Blue,1.76 Kg
# Intel Core i3-13100 Desktop Processor 4 cores (4 P-cores + 0 E-cores) 12MB Cache, up to 4.5 GHz
# Intel Core i5-14400F Desktop Processor 10 cores (6 P-cores + 4 E-cores) up to 4.7 GHz
# Intel NUC 13 Pro NUC13ANHi7 Barebone System - Socket BGA-1744-1 x Processor Support Core i7 13th Gen i7-1360P Dodeca-core (12 Core),Black
# Intel® Core™ i7-14700KF New Gaming Desktop Processor 20 cores (8 P-cores + 12 E-cores) - Unlocked
# LG Electronics Gram14-2023 Intel 13Thgen Evo I5-1340P IPS Anti-Glare 16:10/16Gb Lpddr5 Ram/512Gb Ssd/Intel Iris Xe Graphic/Wuxga/Face-Login/Mil-Std/Rr 60Hz/72Wh/3Yr Warranty-Windows 11 Home
# Intel Core i3-14100F Desktop Processor 4 cores (4 P-cores + 0 E-cores) up to 4.7 GHz
# Intel CoreTM i5-14600K LGA 1700 Socket New Gaming Desktop Processor 14 (6 P-cores + 8 E-cores) with Integrated Graphics - Unlocked
# Intel Core i5-14500 Desktop Processor 14 cores (6 P-cores + 8 E-cores) up to 5.0 GHz
# Intel Core i5-14400 Desktop Processor 10 cores (6 P-cores + 4 E-cores) up to 4.7 GHz
# Intel® Core™ i9-14900K New Gaming Desktop Processor 24 cores (8 P-cores + 16 E-cores) with Integrated Graphics - Unlocked
# ASUS Vivobook 16 (2023), Intel Core i5-1335U 13th Gen, 16" (40.64 cms) FHD+, Thin and Light Laptop (16GB/512GB SSD/Intel Iris Xᵉ/Win 11/Office 2021/Backlit KB/Silver/1.88 kg), X1605VAB-MB544WS
# ASUS Vivobook 15 (2023), Intel Core i5-1335U 13th Gen, 15.6" (39.62 cms) FHD, Thin and Light Laptop (8GB/512GB SSD/Intel Iris Xᵉ/Win 11/Office 2021/Fingerprint/Silver/1.7 kg), X1504VA-NJ524WS
# Intel Realsense Depth Camera D435I With Imu Upto 1080P - Digital, Grey
# ASUS Vivobook 15, Intel Core i3-1220P 12th Gen, 15.6" (39.62 cm) FHD, Thin and Laptop (8GB/512GB SSD/Integrated Graphics/Windows 11/Office 2021/Fingerprint/Blue/1.7 kg), X1502ZA-EJ385WS
# Intel Core i3-10100F 10th Generation LGA1200 Desktop Processor 4, 4 Cores 8 Threads up to 4.30GHz 6MB Cache
# Intel Core i7 12700 12th Gen Generation Desktop PC Processor CPU APU with 25MB Cache and up to 4.90 GHz Clock Speed 3 Years Warranty with Fan LGA 1700 4K (Graphic Card Not Required)
# Intel Core I5-13400 Processor 20M Cache, Up to 4.60 Ghz, LGA 1700
# Intel Core I5-13400F Processor 20M Cache, Up to 4.60 Ghz, LGA 1700
# Intel Core i5-13500 Processor, LGA 1700, 24M Cache, up to 4.80 GHz
# Intel Core i5-12400 Desktop Processor 18M Cache, up to 4.40 GHz LGA 1700 Socket
# HP Pavilion Plus 13th Gen Intel EVO Core i5-1340P 14inch(35.6 cm), Metal Body,TUV Certified 2.2K,Micro Edge Display(16GB RAM/512GB SSD/B&O/5MP Camera/Intel Iris Xe Graphics/FPR/MSO/Win 11,14-eh1022TU
# Lenovo V14 Intel Core I3 11th Gen 14" Thin and Light Laptop (8GB RAM/256GB SSD/Windows 11/Iron Grey/1.5 kg)
# Dell 15 Thin & Light Laptop, Intel Core 13th Generation i5-1334U Processor, 16GB DDR4 & 512GB SSD, 15.6" (39.62cm) FHD 120Hz 250 nits, Win 11 + MSO'21 + 15 Month Mcafee, Carbon Black, 1.66kg
# Lenovo ThinkPad E14 Intel Core i5 13th Gen 14" WUXGA IPS 300 Nits Thin and Light Laptop (16GB RAM/512GB SSD/Windows 11 Home/Office 2021/Backlit Keyboard/FPR/Black/1.41 kg), 21JKS0UA00
# HP Laptop 14, Intel® Core™ i3-1215U, 14-inch(35.6 cm), FHD,8GB DDR4,512GB SSD,MSO,Dual Speakers,Win 11,Silver, 1.46 kg,14s-dq5138TU
# Intel Core I9-13900K Processor 36M Cache, Up to 5.80 Ghz, LGA 1700
# Lenovo V14 G3 IAP Laptop 12th Generation Intel Core i3-1215U / 8GB DDR4 / 512 GB SSD PCIe / 14.0 FHD TN Display/Windows 11/Ms-Office/Silver (Grey) / 1 Year Onsite Warranty
# Acer Aspire Lite 12th Gen Intel Core i3-1215U Premium Metal Laptop (Windows 11 Home/8 GB RAM/512GB SSD) AL15-52, 39.62cm (15.6") Full HD Display, Metal Body, Steel Gray, 1.59 Kg
# Dell 14 Thin & Light Laptop, 12th Gen Intel Core i3-1215U Processor/8GB/512GB SSD/Intel UHD Graphics/14.0"(35.56cm) FHD/Windows 11 + MSO'21/15 Month McAfee/Spill-Resistant Keyboard/Grey/1.48kg
# Intel Pentium Gold G6405 10th Gen Generation Desktop PC Processor Box CPU APU 4MB Cache 4.10 Clock Speed 3 Years Warranty with Fan LGA 1200 Socket (Graphics Card Not Required)
# Intel® Core™ i9-13900F Processor 36M Cache, up to 5.60 GHz
# Intel Core i5 12600K 12 Gen Generation Desktop PC Processor CPU with 20MB Cache and up to 4.90 GHz Clock Speed 3 Years Warranty with Fan LGA 1700 Socket No Graphic Card Required
# Intel Core i5-11400F Desktop Processor 6, 6 Cores up to 4.4 GHz LGA1200 (500 Series and Select 400 Series Chipset) 65W
# Intel Core i7-11700F 11th Gen Generation Desktop PC Processor CPU with 16 MB Cache and up to 4.90 GHz Clock Speed 3 Years Warranty Support LGA 1200 Socket (Graphic Card Mandatory)
# Intel® Core™ i7-13700F Processor 30M Cache, up to 5.20 GHz
# ASUS Vivobook 15 (2023), Intel Core I5-13500H 13Th Gen, 15.6" (39.62 Cms) Fhd, Thin and Light Laptop (16Gb/512Gb Ssd/Intel Iris X?/Win 11/Office 2021/Backlit Kb/Blue/1.7 Kg), X1502Va-Nj541Ws
# Intel NUC 12 NUC12WSHi7 Wall Street Canyon Mini Computer 12th Gen Core i7-1260P, 12 Cores(4P+8E), 16 Threads, 18MB Smart Cache, Iris Xe Graphics,0GB RAM, 0GB SSD, No OS, Barebone
# Intel Core i3-10105F LGA1200 Desktop Processor 4 Cores 8 Threads up to 4.40GHz 6MB Cache
# Intel Core I7 12700Kf 12Th Gen Desktop Processor 25 Mb Cache, Up to 5.00 Ghz Clock Speed 12 Core 20 Threads 125W Lga 1700 Socket 3 Years Warranty Box Packaging Ddr4 Ddr5 Ram Support
# Core i5-3470 3.2GHz 5.0GT s 6MB LGA 1155 CPU OEM Processor
# Intel NUC 12 Pro Wall Street Canyon NUC12WSHi5, 12TH GEN Intel Core i5-1240P 12-Core, 16 threads, 12MB L3 Cache, Upto 4.4 GHz Turbo, 28W Intel Iris Xe Graphics, Barebone, No RAM, NO SSD, No OS.
# ASUS Prime H510M-E R2.0 Intel H470 LGA 1200 Micro ATX Motherboard with PCIe 4.0, 32Gbps M.2 Slot, DisplayPort/HDMI™/VGA, USB 3.2 Gen 1 Ports, SATA 6 Gbps, Aura Addressable Gen 2
# Intel Core i5-11600KF Desktop Processor 1, 6 Cores up to 4.9 GHz Unlocked LGA1200 (500 Series & Select 400 Series Chipset) 125W
# Intel® Core i5-9400F Processor (9M Cache, up to 4.10 GHz) LGA 1151 Socket
# Intel Core i5-10400F 10th Generation Processor with 12MB Cache Memory 6 Cores 12 Threads and 3 Years Warranty (Comes with Fan Inside The Box)
# Intel® Core™ i5-14600KF New Gaming Desktop Processor 14 cores (6 P-cores + 8 E-cores) - Unlocked
# Intel Core i5-10th Gen Processor (i5-10600K LGA 1200, 4.1 GHZ, 12 MB Cache)
# Intel Core i5-11400 Desktop Processor 1, 6 Cores up to 4.4 GHz LGA1200 (500 Series & Select 400 Series Chipset) 65W
# IntelCorei9-10900X X-Series Processor (19.25M Cache, 3.70 GHz) LGA 2066
# Intel Core i9-13900KS Desktop Processor 24 cores (8 P-cores + 16 E-cores) 36MB Cache, up to 6.0 GHz
# Intel Core i9-14900 Desktop Processor 24 cores (8 P-cores + 16 E-cores) up to 5.8 GHz
# Intel Core i9-11900 LGA1200 Desktop Processor 8 Cores up to 5.1GHz 16MB Cache with Integrated Intel UHD 750 Graphics
# Lenovo ThinkBook 15 Intel 12th Gen Core i5 15.6" (39.62cm) FHD 250 nits Antiglare Thin and Light Laptop (16GB/512GB SSD/Win 11 Home/Office 2021/Backlit Keyboard/Mineral Grey/1.7 Kg), 21DJA0FGIH
# Intel® Core™ i7-14700K New Gaming Desktop Processor 20 cores (8 P-cores + 12 E-cores) with Integrated Graphics - Unlocked
# HP Pavilion Laptop 13th Gen Intel Core i5-1340P 15.6 inch(39.6cm) FHD IPS Laptop(16GB RAM /512GB SSD/Intel Iris Xe Graphics/Win 11/MSO 2021/Backlit Keyboard/FPR/B&O/Alexa/Natural Silver) 15-eg3079TU
# Intel Core I7-13700F Desktop Processor 16 Cores (8 P-Cores + 8 E-Cores) 30Mb Cache,Up to 5.2 Ghz,LGA 1151
# ZEBRONICS PRO Series Z NBC 4S, Intel Core 12th Gen i5 Processor 16GB RAM & 512GB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Blue, 1.76 Kg
# Intel Realsense L515 Lidar Depth Camera (Black)
# Lenovo IdeaPad Slim 5 Intel Core i7 13700H 16"(40.6cm) WUXGA IPS Laptop (16GB/512GB SSD/Win 11/Office 2021/Backlit KB/FHD Camera/Alexa/3 Month Game Pass/Cloud Grey/1.89Kg), 82XF003JIN
# ZEBRONICS PRO Series Z NBC 5S, Intel Core 12th Gen i7 Processor 16GB RAM & 1TB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Space Grey, 1.76 Kg
# Lenovo IdeaPad Pro 5 Intel Core i7 13700H 16 Inch (40.6cm) 2.5K IPS 350Nits 120Hz Laptop (16GB/1TB SSD/NVDIA RTX 3050/Win 11/MSOffice/Backlit/FHD Camera/Alexa/3 month Game Pass/Grey/1.95Kg),83AQ005SIN
# ZEBRONICS PRO Series Z NBC 5S, Intel Core 12th Gen i7 Processor 16GB RAM & 512GB SSD Laptop, 15.6 Inch (39.6CM), IPS 180° Display, Dolby Atmos, 38.5Wh Large Battery, Windows 11, Blue, 1.76 Kg
# Intel Core i9-9900KS Desktop Processor 8 Cores up to 5.0GHz All-Core Turbo Unlocked LGA1151 Z390 127W
# Intel Core i9 (12th Gen) i9-12900KS Hexadeca-core (16 Core) 2.50 GHz Processor
# Intel Core i7-12700K Desktop Processor 12 (8P+4E) Cores up to 5.0 GHz Unlocked LGA 1700 600 Series Chipset 125W
# Intel NUC 11 Pro Slim Kit, 11th Gen, Core i3-1115G4, 8 GB DDR4 RAM, 256 GB SSD, RJ-45, WiFi-6,Bluetooth, HDMI, Windows 11 Pro, Mini PC + NPO Cord
# HP Laptop 15, 12th Gen Intel® Core™ i3-1215U,15.6-inch(39.6 cm),FHD,Anti-Glare,MSO,8GB DDR4 (3200MHz),512GB SSD,Dual Speakers,Windows 11,Natural Silver,1.69kg, 15s-fq5007TU
# Intel Core i7-11700K LGA1200 Desktop Processor 8, 8 Cores up to 5GHz 16MB Cache with Integrated UHD 750 Graphics
# Intel® Core i5-10400 Processor (12M Cache, up to 4.30 GHz) BGA 437 Socket
# Intel Core i3-14100 Desktop Processor 4 cores (4 P-cores + 0 E-cores) up to 4.7 GHz
# Intel Core i5-12600K Desktop Processor 10 (6P+4E) Cores up to 4.9 GHz Unlocked Socket LGA 1700 600 Series Chipset 125W
# Intel Core i3-10100 (Base Clock 3.60GHz; Socket LGA1200; 65 Watt) Box
# Intel® Core i7-9700K Processor (12M Cache, up to 4.90 GHz) LGA 1151 Socket
# Intel® Core™ i7-9700F Processor (12M Cache, up to 4.70 GHz)
# Intel ® Core i7-10700 Processor FCLGA1200 Sockets (16M Cache, up to 4.80 GHz)
# Intel 7th Gen Intel Core Desktop Processor i7-7700K (BX80677I77700K)
# Intel Core i7-7700K Unlocked Processor 8M Cache, up to 4.50 GHz, Quad-Core Kaby Lake
# Intel Core i7 7700K Processor
# Intel Cpu Core 2 Quad Q6600 2.4Ghz Fsb1066Mhz 8M Lga775 Tray
# INTEL E10GSFPSR INTEL 10G SFP SR SFP
# Intel® Core™ i7-7700 Processor 8M Cache, up to 3.60 GHz 7th Generation Intel® Core™ i7 Processors
# Intel Core i9-12900KF Desktop Processor16 (8P+8E) Cores up to 5.2 GHz Unlocked LGA1700 600 Series Chipset 125W
# Intel Core i9-10900F Desktop Processor 10 Cores up to 5.2 GHz Without Processor Graphics LGA 1200 (Intel 400 Series chipset) 65W
# Intel ARC A380 6GB GDDR6 Gaming Ray Tracing Graphics Card (PCIe 4.0, 4K & 8K Resolution Support, Vulkan 1.3, X Cores, XMX Engines, X Vector) Streaming, Content Creation, AI, VR Ready, Gamer GPU
# Intel Core i9 12900 12th Gen Desktop Processor 30MB Cache, up to 5.10 GHz Clock Speed 16 Cores 24 Threads UHD 770 Graphics 3 Years Warranty Graphic Card not Mandatory Comes with Fan Inside The Box
# Intel PENTIUM Gold G6400 Desktop 10th GEN Processor 1, 2 CORE UP to 4 GHZ 4MB Smart Cache LGA1200 (400 Series CHIPSET) 58W BX80701G6400
# Intel Core i7-990X Extreme Edition Processor 3.46 GHz 6 Core LGA 1366 CPU - OEM
# Intel® Core i3-10100 Processor (6M Cache, up to 4.30 GHz) BGA 437 Socket
# G1 Thin Pcs G1 Thin Client Pc-4 Lan Mini Pc|Intel J4125 Mini Computer Barebone-Used For Firewall,Pfsense|Runs 24/7 Without Any Heating Issues..,ubuntu&windows,Black
# Intel Core i9 9900K OEM 8-Core, 16-Thread, 3.6 GHz (5.0 GHz Turbo) LGA 1151 (300 Series) 95W BX80684I99900K Desktop Processor Intel UHD Graphics 630
# Intel Core i9 i9-10980XE Octadeca-core (18 Core) 3 GHz Processor - 24.75 MB Cache - 4.60 GHz Overclocking Speed - 14 nm - 165 W - 36 Threads LGA 2066 Socket
# Intel® Core™ i9-13900KF Processor 36M Cache, up to 5.80 GHz
# Intel® Core™ i9-13900 Processor 36M Cache, up to 5.60 GHz
# Intel® Core™ i9-9900 Processor (16M Cache, up to 5.00 GHz)
# ASRock Intel Socket LGA1200 Intel H470 Black Mini/Booksize Barebone System Model DESKMINI H470W
# Intel® Core™ i9-9900X X-Series Processor (19.25M Cache, up to 4.50 GHz)
# INTEL Desktop Processor I5-9400F 2.9GHZ,9MB Cache,LGA1151 3YEARS Warranty
# Intel Core i9-10920X Desktop Processor 12 Cores up to 4.8GHz Unlocked LGA 2066 Socket X299 Series 165W
# Matrix X-Stream Edition | 128GB | M.2 - SSD | Internal Solid State Drive High Reliability & Stability for Laptops/Desktops (128GB)
# Intel Copper Core Socket 478 Heat Sink and Fan up to 3.4GHz
# Intel SSDSC2KB240G701 S4500 Series 240gb 2.5 In
# Tp-Link Tx201 2.5 Gigabit Pci Express Network Adapter, Low-Profile and Full-Height Brackets, Supports Windows 11/10/8.1/8/7, 2.5Gbps WiFi Pcie Card, Qos - Black
# Intel 6th Gen I3 NUC BOXNUC6I3SYHL
# Intel Core i7-3632QM 2.20GHz Quad-Core CPU 6M 5.0GTS Socket G2 SR0V0 OEM
# Intel Core i7-14700 Desktop Processor 20 cores (8 P-cores + 12 E-cores) up to 5.4 GHz
# INTEL Pentium Processor G2010 3M Cache, 2.80 GHz LGA1155, Dual Core and Ivy Bridge(BX80637G2010) LGA 1155
# Intel® Core™ i9-9960X X-Series Processor (22M Cache, up to 4.50 GHz)
# Intel Core i5-10600KF (Base Clock: 4.10GHz; LGA1200; 125 Watt) Box
# Intel Core i7-13700 Desktop Processor 16 cores (8 P-cores + 8 E-cores) 30MB Cache, up to 5.2 GHz
# Intel Core i7-14700F Desktop Processor 20 cores (8 P-cores + 12 E-cores) up to 5.4 GHz
# Intel Core i9 7960X - LGA2066 - For X299 Chipset Board (X-Series ,16 Cores, 32 Threads, 22M Cache, up to 4.20 GHz, 44 PCI Express Lanes) LGA 2066
# INTEL Core i5-3470 Ivy Bridge 3.2GHz 5.0GT s 6MB LGA 1155 CPU OEM Processor
# Intel NUC 13 Pro NUC13ANHi5 Barebone System - Socket BGA-1744-1 x Processor Support Core i5 13th Gen i5-1340P Dodeca-core (12 Core)
# Core i3 2120 2nd Generation 3.3 GHz LGA 1155 Socket Desktop Processor
# AD Core i3 2120 2nd Generation 3.3 GHz LGA 1155 Socket Desktop Processor (Silver)
# Matrix 256GB M.2 (2280) Internal Solid State Drive (SSD), Read Up to 560MB/s, Write Up to 500MB/s, 5 Year Warranty
# ZEBRONICS H55 Micro-ATX Motherboard for LGA 1156 Socket, Supports Intel 1st Generation Processors, DDR3 1333 MHz, Ports (RJ45 | SATA | USB | HDMI | VGA)
# MATRIX 128GB 3D NAND Flash SATA 6GB/s 2.5 Inches Internal Solid State Drive (SSD), Read Up to 550MB/s, Write Up to 500MB/s, 5 Year Warranty
# GIGABYTE B560M Ds3H (Lga 1200/ Intel/ B560/ Micro-Atx/Dual M.2/ Pcie 4.0/ Usb 3.2 Gen1/ Gbe Lan/Motherboard), ddr_4
# Intel® Core i7-4790K Unlocked 4.0 GHz Quad Core LGA1150 Socket Processor (8M Cache, up to 4.40 GHz)
# Intel® Core™ i9-11900KF Desktop Processor 8 Cores up to 5.3 GHz Unlocked LGA1200 (Intel® 500 Series & Select 400 Series Chipset) 125W
# Intel M.2 AC 9260 WiFi Card with Bluetooth 5.1 | Up to 1.73Gbps, MU-MIMO, WiFi 5 | Works with Intel, AMD, Linux & Windows 10/11 | Non-vPro | Model 9260NGW WiFi Adapter (AC9260)
# Intel Xeon Gold 6230 Icosa-core (20 Core) 2.10 GHz Processor - OEM Pack
# Intel® Core™ i3-13100F Processor 12M Cache, up to 4.50 GHz
# Intel® Core™ i7-13700 Processor 30M Cache, up to 5.20 GHz
# Intel Core i9-9900K Desktop Processor 8 Cores up to 5.0GHz Unlocked LGA1151 300 Series 95W
# Intel Core i9-14900F Desktop Processor 24 cores (8 P-cores + 16 E-cores) up to 5.8 GHz
# Intel Core i3-4130 FCLGA 1150 Processor
# Intel Core i9-9900KF Desktop Processor
# Intel Core i9-7920X X-Series Processor 12 Cores up to 4.3 GHz Turbo Unlocked LGA2066 X299 Series 140W (Tray)
# Intel® Core™ i9-9980XE Extreme Edition Processor (24.75M Cache, up to 4.50 GHz)
# Intel® Core™ i9-14900KF New Gaming Desktop Processor 24 cores (8 P-cores + 16 E-cores) - Unlocked
# Intel - CM8064601466200 - Intel Core i7 i7-4765T Quad-core (4 Core) 2 GHz Processor - Socket H3 LGA-1150OEM Pack - 1 MB - 8 MB Cache - Yes - 3 GHz Overclocking Speed - 22 nm - 3 Number of Monitors Sup
# Intel Core i7 6700K BX80662I76700K Socket LGA1151 Processor (Blue)
# Intel Bx80673I97940X CPU Grey

# %%
def extract_info(row):
    # Split the text by spaces
    parts = row.split()
    # Extract relevant information
    brand = parts[0]
    try:
        # Extracting model till 'Processor' for processors
        if 'Processor' in row:
            model = ' '.join(parts[1:parts.index('Processor')])
        else:
            model = 'N/A'
    except ValueError:
        # If the keyword is not found, set model as N/A
        model = 'N/A'
    return pd.Series([brand, model])

# Apply the function to the DataFrame and concatenate the results
df[['Brand', 'Model']] = df['Product'].apply(extract_info)

# Drop the original column
df.drop('Product', axis=1, inplace=True)

# Display the resulting DataFrame
print(df)
# Out:
#         Rating                                            Reviews  \
# 0          5.0  Fast CPU and since I did not need the graphics...
# 1          5.0                                              Fast.
# 2          5.0  Fast CPU and since I did not need the graphics...
# 3          5.0  This processor is absolutely incredible with n...
# 4          5.0  Most powerful cpu at this price bracket no dou...
# ...        ...                                                ...
# 110996     1.0                        Not at all working fake one
# 110997     5.0                            Un mostro di processore
# 110998     5.0  Zum Schneiden und Bearbeiten bestens geeignet....
# 110999     5.0  Puro poder de procesador. Honestamente para lo...
# 111000     5.0  Für Videoschnitt in Verbindung mit Wasserkühlu...
#
#                  Location               Date  Brand  \
# 0       the United States  27 September 2022  Intel
# 1       the United States  17 September 2023  Intel
# 2       the United States  27 September 2022  Intel
# 3                   India   3 September 2023  Intel
# 4                   India      28 March 2023  Intel
# ...                   ...                ...    ...
# 110996              India       17 June 2020  Intel
# 110997              Italy   19 November 2018  Intel
# 110998            Germany        2 July 2018  Intel
# 110999              Spain        20 May 2019  Intel
# 111000            Germany         8 May 2018  Intel
#
#                                                     Model
# 0       Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 1       Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 2       Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 3                                  Core i7-13700K Desktop
# 4                                  Core i7-13700K Desktop
# ...                                                   ...
# 110996                                                N/A
# 110997                                                N/A
# 110998                                                N/A
# 110999                                                N/A
# 111000                                                N/A
#
# [111001 rows x 6 columns]

# %%
# Remove rows where Model is 'N/A'
df = df[df['Model'] != 'N/A']

# Standardize the Brand column
df['Brand'] = df['Brand'].str.replace('Intel®', 'Intel', regex=False)
df['Brand'] = df['Brand'].str.replace('INTEL', 'Intel', regex=False)

# Remove rows where Model is 'N/A'
df = df[df['Model'] != 'N/A']

# Remove rows where Brand doesn't come under Intel
df = df[df['Brand'] == 'Intel']

# Reset the index
df.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df
# Out:
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\1754357483.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brand'] = df['Brand'].str.replace('Intel®', 'Intel', regex=False)
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\1754357483.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Brand'] = df['Brand'].str.replace('INTEL', 'Intel', regex=False)
#        Rating                                            Reviews  \
# 0         5.0  Fast CPU and since I did not need the graphics...
# 1         5.0                                              Fast.
# 2         5.0  Fast CPU and since I did not need the graphics...
# 3         5.0  This processor is absolutely incredible with n...
# 4         5.0  Most powerful cpu at this price bracket no dou...
# ...       ...                                                ...
# 66488     5.0  the review is good anyway being an intel produ...
# 66489     5.0  good service by amazon,  my pros. k380 , deepc...
# 66490     5.0  Ultra fast 6th gen skylake processor , great f...
# 66491     5.0  I have used several older models of NUC before...
# 66492     5.0  These little NUCs are great.  They are really ...
#
#                 Location               Date  Brand  \
# 0      the United States  27 September 2022  Intel
# 1      the United States  17 September 2023  Intel
# 2      the United States  27 September 2022  Intel
# 3                  India   3 September 2023  Intel
# 4                  India      28 March 2023  Intel
# ...                  ...                ...    ...
# 66488              India       14 July 2016  Intel
# 66489              India    4 December 2015  Intel
# 66490              India      18 March 2016  Intel
# 66491  the United States       11 July 2023  Intel
# 66492  the United States  19 September 2023  Intel
#
#                                                    Model
# 0      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 1      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 2      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...
# 3                                 Core i7-13700K Desktop
# 4                                 Core i7-13700K Desktop
# ...                                                  ...
# 66488        Core i7 6700K BX80662I76700K Socket LGA1151
# 66489        Core i7 6700K BX80662I76700K Socket LGA1151
# 66490        Core i7 6700K BX80662I76700K Socket LGA1151
# 66491  NUC 13 Pro NUC13ANHi7 Barebone System - Socket...
# 66492  NUC 13 Pro NUC13ANHi7 Barebone System - Socket...
#
# [66493 rows x 6 columns]

# %%
# Function to extract Core series (i3, i5, i7, i9)
def extract_core_series(model):
    match = re.search(r'i[3579]', model)
    return match.group() if match else 'N/A'

# Function to extract generation
def extract_generation(model):
    match = re.search(r'i[3579]-(\d{4})|i[3579] (\d{4})', model)
    if match:
        return int(match.group(1) or match.group(2)) // 100
    return 'N/A'

# Apply the functions to create new columns using .loc
df.loc[:, 'Core_Series'] = df['Model'].apply(extract_core_series)
df.loc[:, 'Generation'] = df['Model'].apply(extract_generation)

# Remove rows where Core_Series or Generation is 'N/A'
df = df[(df['Core_Series'] != 'N/A') & (df['Generation'] != 'N/A')]

# Reset the index
df.reset_index(drop=True, inplace=True)

# Display the resulting DataFrame
df
# Out:
#        Rating                                            Reviews  \
# 0         5.0  Fast CPU and since I did not need the graphics...
# 1         5.0                                              Fast.
# 2         5.0  Fast CPU and since I did not need the graphics...
# 3         5.0  This processor is absolutely incredible with n...
# 4         5.0  Most powerful cpu at this price bracket no dou...
# ...       ...                                                ...
# 55276     5.0                    Intel Core i7 6700K is a beast.
# 55277     5.0  I bought this over 7700k cuz I could still ove...
# 55278     5.0  the review is good anyway being an intel produ...
# 55279     5.0  good service by amazon,  my pros. k380 , deepc...
# 55280     5.0  Ultra fast 6th gen skylake processor , great f...
#
#                 Location               Date  Brand  \
# 0      the United States  27 September 2022  Intel
# 1      the United States  17 September 2023  Intel
# 2      the United States  27 September 2022  Intel
# 3                  India   3 September 2023  Intel
# 4                  India      28 March 2023  Intel
# ...                  ...                ...    ...
# 55276              India      1 August 2016  Intel
# 55277              India    9 February 2017  Intel
# 55278              India       14 July 2016  Intel
# 55279              India    4 December 2015  Intel
# 55280              India      18 March 2016  Intel
#
#                                                    Model Core_Series  \
# 0      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...          i9
# 1      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...          i9
# 2      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...          i9
# 3                                 Core i7-13700K Desktop          i7
# 4                                 Core i7-13700K Desktop          i7
# ...                                                  ...         ...
# 55276        Core i7 6700K BX80662I76700K Socket LGA1151          i7
# 55277        Core i7 6700K BX80662I76700K Socket LGA1151          i7
# 55278        Core i7 6700K BX80662I76700K Socket LGA1151          i7
# 55279        Core i7 6700K BX80662I76700K Socket LGA1151          i7
# 55280        Core i7 6700K BX80662I76700K Socket LGA1151          i7
#
#       Generation
# 0             12
# 1             12
# 2             12
# 3             13
# 4             13
# ...          ...
# 55276         67
# 55277         67
# 55278         67
# 55279         67
# 55280         67
#
# [55281 rows x 8 columns]

# %%
# Rearrange the columns
df = df[['Brand', 'Core_Series', 'Generation','Model', 'Rating', 'Date', 'Location','Reviews']]
df
# Out:
#        Brand Core_Series Generation  \
# 0      Intel          i9         12
# 1      Intel          i9         12
# 2      Intel          i9         12
# 3      Intel          i7         13
# 4      Intel          i7         13
# ...      ...         ...        ...
# 55276  Intel          i7         67
# 55277  Intel          i7         67
# 55278  Intel          i7         67
# 55279  Intel          i7         67
# 55280  Intel          i7         67
#
#                                                    Model  Rating  \
# 0      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...     5.0
# 1      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...     5.0
# 2      Core i9 (12th Gen) i9-12900F Hexadeca-core (16...     5.0
# 3                                 Core i7-13700K Desktop     5.0
# 4                                 Core i7-13700K Desktop     5.0
# ...                                                  ...     ...
# 55276        Core i7 6700K BX80662I76700K Socket LGA1151     5.0
# 55277        Core i7 6700K BX80662I76700K Socket LGA1151     5.0
# 55278        Core i7 6700K BX80662I76700K Socket LGA1151     5.0
# 55279        Core i7 6700K BX80662I76700K Socket LGA1151     5.0
# 55280        Core i7 6700K BX80662I76700K Socket LGA1151     5.0
#
#                     Date           Location  \
# 0      27 September 2022  the United States
# 1      17 September 2023  the United States
# 2      27 September 2022  the United States
# 3       3 September 2023              India
# 4          28 March 2023              India
# ...                  ...                ...
# 55276      1 August 2016              India
# 55277    9 February 2017              India
# 55278       14 July 2016              India
# 55279    4 December 2015              India
# 55280      18 March 2016              India
#
#                                                  Reviews
# 0      Fast CPU and since I did not need the graphics...
# 1                                                  Fast.
# 2      Fast CPU and since I did not need the graphics...
# 3      This processor is absolutely incredible with n...
# 4      Most powerful cpu at this price bracket no dou...
# ...                                                  ...
# 55276                    Intel Core i7 6700K is a beast.
# 55277  I bought this over 7700k cuz I could still ove...
# 55278  the review is good anyway being an intel produ...
# 55279  good service by amazon,  my pros. k380 , deepc...
# 55280  Ultra fast 6th gen skylake processor , great f...
#
# [55281 rows x 8 columns]

# %%
distinct_values = df["Model"].unique()

print("Distinct Processors being evaluated:")
for value in distinct_values:
    print(value)
# Out:
# Distinct Processors being evaluated:
# Core i9 (12th Gen) i9-12900F Hexadeca-core (16 Core) 2.40 GHz
# Core i7-13700K Desktop
# Core i7 (12th Gen) i7-12700 Dodeca-core (12 Core) 2.10 GHz
# Core i9-13900K Desktop
# Core i7-13700KF Gaming Desktop
# Core™ i9-13900KS
# Core™ i9-14900KS Desktop
# Core i7 12700F 12 Gen Desktop PC
# Core i5-13600K Desktop
# Core i5 (12th Gen) i5-12500 3 GHz
# Core i3-12100
# Core i3 12100F 12th Gen Generation Desktop PC
# Core i3-13100 Desktop
# Core i5-14400F Desktop
# Core™ i7-14700KF New Gaming Desktop
# Core i3-14100F Desktop
# CoreTM i5-14600K LGA 1700 Socket New Gaming Desktop
# Core i5-14500 Desktop
# Core i5-14400 Desktop
# Core™ i9-14900K New Gaming Desktop
# Core i3-10100F 10th Generation LGA1200 Desktop
# Core i7 12700 12th Gen Generation Desktop PC
# Core i5-12400 Desktop
# Core™ i9-13900F
# Core i5 12600K 12 Gen Generation Desktop PC
# Core i5-11400F Desktop
# Core i7-11700F 11th Gen Generation Desktop PC
# Core™ i7-13700F
# Core i3-10105F LGA1200 Desktop
# Core i5-11600KF Desktop
# Core i5-9400F
# Core i5-10400F 10th Generation
# Core™ i5-14600KF New Gaming Desktop
# Core i5-11400 Desktop
# Core i9-13900KS Desktop
# Core i9-14900 Desktop
# Core i9-11900 LGA1200 Desktop
# Core™ i7-14700K New Gaming Desktop
# Core i9-9900KS Desktop
# Core i9 (12th Gen) i9-12900KS Hexadeca-core (16 Core) 2.50 GHz
# Core i7-12700K Desktop
# Core i7-11700K LGA1200 Desktop
# Core i5-10400
# Core i3-14100 Desktop
# Core i5-12600K Desktop
# Core i7-9700K
# Core™ i7-9700F
# ® Core i7-10700
# Core i7-7700K Unlocked
# Core i7 7700K
# Core™ i7-7700
# Core i9-10900F Desktop
# Core i9 12900 12th Gen Desktop
# Core i3-10100
# Core i9 9900K OEM 8-Core, 16-Thread, 3.6 GHz (5.0 GHz Turbo) LGA 1151 (300 Series) 95W BX80684I99900K Desktop
# Core i9 i9-10980XE Octadeca-core (18 Core) 3 GHz
# Core™ i9-13900KF
# Core™ i9-13900
# Core™ i9-9900
# Core™ i9-9900X X-Series
# Core i9-10920X Desktop
# Core i7-14700 Desktop
# Core™ i9-9960X X-Series
# Core i7-13700 Desktop
# Core i7-14700F Desktop
# Core i5-3470 Ivy Bridge 3.2GHz 5.0GT s 6MB LGA 1155 CPU OEM
# Core i7-4790K Unlocked 4.0 GHz Quad Core LGA1150 Socket
# Core™ i9-11900KF Desktop
# Core™ i3-13100F
# Core™ i7-13700
# Core i9-9900K Desktop
# Core i9-14900F Desktop
# Core i3-4130 FCLGA 1150
# Core i9-9900KF Desktop
# Core i9-7920X X-Series
# Core™ i9-9980XE Extreme Edition
# Core™ i9-14900KF New Gaming Desktop
# - CM8064601466200 - Intel Core i7 i7-4765T Quad-core (4 Core) 2 GHz
# Core i7 6700K BX80662I76700K Socket LGA1151

# %% [markdown]
# ### Data Exploration

# %%
# Summary statistics of numerical features
print("Summary statistics of numerical features:\n", df.describe())

# Total number of reviews
total_reviews = len(df)
print("\nTotal number of reviews:", total_reviews)

# Total number of unique products
unique_products = len(df['Model'].unique())
print("\nTotal number of unique products:", unique_products)

# Percentage of reviews with neutral sentiment
neutral_percentage = (df[df['Rating'] == 3]["Reviews"].count() / total_reviews) * 100
print("\nPercentage of reviews with neutral sentiment: {:.2f}%".format(neutral_percentage))

# Percentage of reviews with positive sentiment
positive_percentage = (df[df['Rating'] > 3]["Reviews"].count() / total_reviews) * 100
print("\nPercentage of reviews with positive sentiment: {:.2f}%".format(positive_percentage))

# Percentage of reviews with negative sentiment
negative_percentage = (df[df['Rating'] < 3]["Reviews"].count() / total_reviews) * 100
print("\nPercentage of reviews with negative sentiment: {:.2f}%".format(negative_percentage))
# Out:
# Summary statistics of numerical features:
#               Rating
# count  55281.000000
# mean       4.406867
# std        1.254750
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000
#
# Total number of reviews: 55281
#
# Total number of unique products: 79
#
# Percentage of reviews with neutral sentiment: 3.06%
#
# Percentage of reviews with positive sentiment: 84.73%
#
# Percentage of reviews with negative sentiment: 11.63%

# %% [markdown]
# ### Data Visualization

# %%
# Plot distribution of rating
plt.figure(figsize=(7,3))
# sns.countplot(df['Rating'])
df['Rating'].value_counts().sort_index().plot(kind='bar')
plt.title('Distribution of Rating')
plt.xlabel('Rating')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Plot number of reviews for top 10
brands = df["Model"].value_counts()
# brands.count()
plt.figure(figsize=(7,3))
brands[:10].plot(kind='bar')
plt.title("Number of Reviews for Top 10 Highest-Reviewed Processors")
# Out:
# Text(0.5, 1.0, 'Number of Reviews for Top 10 Highest-Reviewed Processors')

# %%
# Plot distribution of review length
review_length = df["Reviews"].dropna().map(lambda x: len(x))
plt.figure(figsize=(7,3))
review_length.loc[review_length < 1500].hist()
plt.title("Distribution of Review Length")
plt.xlabel('Review length (Number of character)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Pie chart of Core Series distribution
core_series_counts = df['Core_Series'].value_counts()
axs[0, 0].pie(core_series_counts, labels=core_series_counts.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette("Set2"))
axs[0, 0].set_title('Distribution of Core Series')

# Plot 2: Violin plot of Ratings by Core Series
sns.violinplot(data=df, x='Core_Series', y='Rating', palette='Set2', ax=axs[0, 1])
axs[0, 1].set_title('Rating Distribution by Core Series')
axs[0, 1].set_ylim(0, 5)

# Plot 3: Box plot of Ratings by Generation
sns.boxplot(data=df, x='Generation', y='Rating', palette='Set2', ax=axs[1, 0])
axs[1, 0].set_title('Rating Distribution by Generation')
axs[1, 0].set_ylim(0, 5)

# Plot 4: Scatter plot of Rating vs. Generation
sns.scatterplot(data=df, x='Generation', y='Rating', hue='Core_Series', palette='Set2', s=100, ax=axs[1, 1])
axs[1, 1].set_title('Rating vs. Generation')
axs[1, 1].set_ylim(0, 5)
axs[1, 1].set_xlim(df['Generation'].min() - 1, df['Generation'].max() + 1)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\1577005283.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x='Core_Series', y='Rating', palette='Set2', ax=axs[0, 1])
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\1577005283.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Generation', y='Rating', palette='Set2', ax=axs[1, 0])

# %% [markdown]
# ---
# <a id="part2"></a>
# ## Part 2. Data Preparation

# %% [markdown]
# For illustrative purpose, I use only 10% of the data in this project. To simply the problem, I only consider reviews with positive sentiment (rating = 4, 5) and negative sentiment (rating = 1, 2), and drop reviews with neutral sentiment (rating 3).

# %% [markdown]
# ### Prepare Data

# %%
df = df.sample(frac=1, random_state=71) #uncomment to use full set of data

# Drop missing values
df.dropna(inplace=True)

#Remove any 'neutral' ratings equal to 3
df = df[df['Rating'] != 3]

# Encode 4s and 5s as 1 (positive sentiment) and 1s and 2s as 0 (negative sentiment)
df['Sentiment'] = np.where(df['Rating'] > 3, 1, 0)
df.head(40)
# Out:
#        Brand Core_Series Generation  \
# 42044  Intel          i3         10
# 11401  Intel          i7         13
# 43910  Intel          i7         13
# 3247   Intel          i5         14
# 8671   Intel          i5         14
# 52039  Intel          i3         10
# 2322   Intel          i7         13
# 51799  Intel          i7         47
# 38256  Intel          i3         12
# 7197   Intel          i9         13
# 49552  Intel          i5         10
# 37909  Intel          i9         11
# 15007  Intel          i7         14
# 38515  Intel          i7         11
# 5832   Intel          i5         14
# 39693  Intel          i7         97
# 19840  Intel          i9         14
# 41446  Intel          i7         77
# 33197  Intel          i9         10
# 25425  Intel          i7         11
# 22822  Intel          i9         99
# 53066  Intel          i9         99
# 36478  Intel          i9         10
# 13010  Intel          i3         12
# 21306  Intel          i7         14
# 44648  Intel          i5         11
# 52886  Intel          i9         99
# 1031   Intel          i5         13
# 9508   Intel          i7         12
# 8812   Intel          i7         13
# 8261   Intel          i5         12
# 41143  Intel          i5         14
# 5441   Intel          i7         14
# 49859  Intel          i5         34
# 48274  Intel          i3         10
# 53621  Intel          i3         10
# 11706  Intel          i7         12
# 10884  Intel          i5         13
# 45396  Intel          i7         11
# 10086  Intel          i3         12
#
#                                                    Model  Rating  \
# 42044                                      Core i3-10100     1.0
# 11401                             Core i7-13700K Desktop     5.0
# 43910                     Core i7-13700KF Gaming Desktop     4.0
# 3247   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0
# 8671   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0
# 52039     Core i3-10100F 10th Generation LGA1200 Desktop     5.0
# 2322                              Core i7-13700K Desktop     5.0
# 51799  Core i7-4790K Unlocked 4.0 GHz Quad Core LGA11...     5.0
# 38256      Core i3 12100F 12th Gen Generation Desktop PC     5.0
# 7197                                     Core™ i9-13900F     1.0
# 49552                     Core i5-10400F 10th Generation     4.0
# 37909                      Core i9-11900 LGA1200 Desktop     5.0
# 15007                Core™ i7-14700KF New Gaming Desktop     5.0
# 38515                     Core i7-11700K LGA1200 Desktop     4.0
# 5832                               Core i5-14500 Desktop     5.0
# 39693                                     Core™ i7-9700F     5.0
# 19840                 Core™ i9-14900K New Gaming Desktop     5.0
# 41446                                      Core™ i7-7700     5.0
# 33197   Core i9 i9-10980XE Octadeca-core (18 Core) 3 GHz     5.0
# 25425      Core i7-11700F 11th Gen Generation Desktop PC     5.0
# 22822                             Core i9-9900KS Desktop     5.0
# 53066                                      Core™ i9-9900     5.0
# 36478                             Core i9-10920X Desktop     1.0
# 13010                                      Core i3-12100     5.0
# 21306                Core™ i7-14700KF New Gaming Desktop     5.0
# 44648                             Core i5-11400F Desktop     4.0
# 52886                             Core i9-9900KS Desktop     5.0
# 1031                              Core i5-13600K Desktop     5.0
# 9508   Core i7 (12th Gen) i7-12700 Dodeca-core (12 Co...     5.0
# 8812                      Core i7-13700KF Gaming Desktop     5.0
# 8261                               Core i5-12400 Desktop     5.0
# 41143                              Core i5-14400 Desktop     5.0
# 5441                 Core™ i7-14700KF New Gaming Desktop     5.0
# 49859  Core i5-3470 Ivy Bridge 3.2GHz 5.0GT s 6MB LGA...     5.0
# 48274                     Core i3-10105F LGA1200 Desktop     5.0
# 53621                     Core i3-10105F LGA1200 Desktop     5.0
# 11706  Core i7 (12th Gen) i7-12700 Dodeca-core (12 Co...     5.0
# 10884                             Core i5-13600K Desktop     5.0
# 45396                     Core i7-11700K LGA1200 Desktop     5.0
# 10086      Core i3 12100F 12th Gen Generation Desktop PC     5.0
#
#                     Date            Location  \
# 42044   21 November 2020               India
# 11401       24 July 2023              Canada
# 43910       17 June 2023              France
# 3247      2 January 2024   the United States
# 8671       24 April 2024             Germany
# 52039     3 October 2023               India
# 2322       24 April 2024               Spain
# 51799  10 September 2016               India
# 38256    27 January 2024              Brazil
# 7197        6 March 2024               Italy
# 49552     9 October 2023               India
# 37909       12 June 2021   the United States
# 15007        16 May 2024               Spain
# 38515      1 August 2021               India
# 5832       19 March 2024   the United States
# 39693       19 June 2020              Canada
# 19840      16 March 2024               Italy
# 41446      18 April 2017               India
# 33197   26 February 2023   the United States
# 25425    1 November 2023               Italy
# 22822  29 September 2023   the United States
# 53066       8 April 2021               Japan
# 36478       20 July 2021           Australia
# 13010    1 November 2023               India
# 21306      18 March 2024              Mexico
# 44648       30 June 2022               India
# 52886        2 June 2020               Japan
# 1031       3 August 2023   the United States
# 9508         14 May 2024   the United States
# 8812         14 May 2024              Canada
# 8261     25 October 2023               India
# 41143      30 April 2024   the United States
# 5441       18 March 2024              Mexico
# 49859    13 October 2023               India
# 48274  20 September 2021  the United Kingdom
# 53621       21 June 2022               India
# 11706        23 May 2022              Mexico
# 10884      29 March 2024              Canada
# 45396   18 December 2023   the United States
# 10086       25 June 2023               India
#
#                                                  Reviews  Sentiment
# 42044  Processor box was already open. But thank God ...          0
# 11401  This processor performs well and is a solid pe...          1
# 43910                       Pas de problème pour moi....          1
# 3247   I got this CPU because I've been a long term I...          1
# 8671   The seller posted the item but there was a del...          1
# 52039                                   Kerala Kozhikode          1
# 2322                                     Muy buena marca          1
# 51799  Processor is so fast.Best for gamming & Video ...          1
# 38256                         Muito bom, super recomendo          1
# 7197                                     Davvero deluso!          0
# 49552                 Powerful, stable, easy to install.          1
# 37909  Item arrived faster than promised and in great...          1
# 15007  Buen procesador que te da para poder jugar y r...          1
# 38515  Processor is awesome, it's value for money. Bu...          1
# 5832   This is a great product at a great price that ...          1
# 39693  Now that the 10th gen is out, this is an obsol...          1
# 19840             Beh che dire da un mese che ce l'ho...          1
# 41446  Amazon has got a perfectly good price here.......          1
# 33197  Was eyeing this cpu for my server for a while....          1
# 25425  Inizialmente ero partito per un i5, poi ho not...          1
# 22822  This processor works like new! Don't know if i...          1
# 53066  ゲーミングPCにと考え、選択したけど予想通りのRTX2060のグラボの最高性能を引き出してく...          1
# 36478  Ordered Intel® Core™ i9-10980XE but received I...          0
# 13010  Performance , Quality, Speed ,Value for Money ...          1
# 21306  Viene en una caja pequeña y discreta, hasta me...          1
# 44648  Good processor, have a background check about ...          1
# 52886                             なかなか買えない物なので買って良かったです。          1
# 1031   The Intel Core i5-13600K (Latest Gen) Desktop ...          1
# 9508   I love this CPU, it chunks though decent workl...          1
# 8812                               Description parfaite!          1
# 8261                                               Super          1
# 41143  Intel i5 1440 10 Core/16Thread/with Intel 730 ...          1
# 5441   Viene en una caja pequeña y discreta, hasta me...          1
# 49859  I bought it under 2k. Its value for money prod...          1
# 48274  Too good to not not-leave a review. Got it £75...          1
# 53621  Very good processor in budget, cheaper than of...          1
# 11706  Es un buen procesador viene con un disipador y...          1
# 10884   Words cannot describe the change in performance.          1
# 45396  Benchmarked paired with an EVGA Geoforce 3080 ...          1
# 10086  If you would be building pc just for gaming an...          1

# %%
def is_english(text):
  """Checks if the text is in English using langdetect"""
  try:
    return langdetect.detect(text) == 'en'
  except langdetect.LangDetectException:  # Handle potential errors
    return False

# Drop rows with missing reviews or non-English reviews
df = df[df['Reviews'].notnull() & df['Reviews'].apply(is_english)]

df.head(5)
# Out:
#        Brand Core_Series Generation  \
# 42044  Intel          i3         10
# 11401  Intel          i7         13
# 3247   Intel          i5         14
# 8671   Intel          i5         14
# 51799  Intel          i7         47
#
#                                                    Model  Rating  \
# 42044                                      Core i3-10100     1.0
# 11401                             Core i7-13700K Desktop     5.0
# 3247   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0
# 8671   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0
# 51799  Core i7-4790K Unlocked 4.0 GHz Quad Core LGA11...     5.0
#
#                     Date           Location  \
# 42044   21 November 2020              India
# 11401       24 July 2023             Canada
# 3247      2 January 2024  the United States
# 8671       24 April 2024            Germany
# 51799  10 September 2016              India
#
#                                                  Reviews  Sentiment
# 42044  Processor box was already open. But thank God ...          0
# 11401  This processor performs well and is a solid pe...          1
# 3247   I got this CPU because I've been a long term I...          1
# 8671   The seller posted the item but there was a del...          1
# 51799  Processor is so fast.Best for gamming & Video ...          1

# %%
df.shape
# Out:
# (32076, 9)

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d %B %Y')

# Plot sentiment trends over time
plt.figure(figsize=(7, 3))
df.groupby(df['Date'].dt.to_period('M'))['Sentiment'].mean().plot(kind='line')
plt.title('Sentiment Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Average Sentiment')
plt.show()

# %%
# Convert 'Date' column to datetime format
df['Date'] = pd.to_datetime(df['Date'])

# Group data by date and sentiment, count occurrences, and unstack the result
sentiment_trend = df.groupby(['Date', 'Sentiment']).size().unstack(fill_value=0)

# Plot the sentiment trends over time
sentiment_trend.plot(kind='line', figsize=(7, 4))

# Add title and labels
plt.title('Sentiment Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Reviews')

# Show plot
plt.show()

# %%
location_sentiment_count = df.groupby(['Location', 'Sentiment']).size().unstack(fill_value=0)

# Plot the sentiment counts for each location
location_sentiment_count.plot(kind='bar', stacked=True, figsize=(7, 3))

# Add title and labels
plt.title('Sentiment Distribution by Location')
plt.xlabel('Location')
plt.ylabel('Number of Reviews')

# Show legend
plt.legend(title='Sentiment')

# Show plot
plt.show()

# %%
import seaborn as sns

# Select columns for the heatmap
columns = ['Rating', 'Sentiment']

# Compute the correlation matrix
correlation_matrix = df[columns].corr()

# Generate the heatmap
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Now we remove Brand column as it is redundant
df.drop(columns=['Brand'], inplace=True)
df
# Out:
#       Core_Series Generation  \
# 42044          i3         10
# 11401          i7         13
# 3247           i5         14
# 8671           i5         14
# 51799          i7         47
# ...           ...        ...
# 38945          i3         10
# 50086          i3         10
# 47866          i7         77
# 35553          i9         14
# 15583          i7         13
#
#                                                    Model  Rating       Date  \
# 42044                                      Core i3-10100     1.0 2020-11-21
# 11401                             Core i7-13700K Desktop     5.0 2023-07-24
# 3247   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0 2024-01-02
# 8671   CoreTM i5-14600K LGA 1700 Socket New Gaming De...     5.0 2024-04-24
# 51799  Core i7-4790K Unlocked 4.0 GHz Quad Core LGA11...     5.0 2016-09-10
# ...                                                  ...     ...        ...
# 38945                     Core i3-10105F LGA1200 Desktop     5.0 2024-04-27
# 50086     Core i3-10100F 10th Generation LGA1200 Desktop     4.0 2021-07-10
# 47866                                      Core™ i7-7700     5.0 2017-11-07
# 35553                 Core™ i9-14900K New Gaming Desktop     1.0 2024-03-28
# 15583                     Core i7-13700KF Gaming Desktop     5.0 2024-04-05
#
#                  Location                                            Reviews  \
# 42044               India  Processor box was already open. But thank God ...
# 11401              Canada  This processor performs well and is a solid pe...
# 3247    the United States  I got this CPU because I've been a long term I...
# 8671              Germany  The seller posted the item but there was a del...
# 51799               India  Processor is so fast.Best for gamming & Video ...
# ...                   ...                                                ...
# 38945  the United Kingdom  Really good and can basically run any game I t...
# 50086               India  If you are buying this processor you need to h...
# 47866               India  First of all thanks to the B Online Store for ...
# 35553               India                    I don't liked the price of it .
# 15583   the United States  This cpu is really amazing at everything. It d...
#
#        Sentiment
# 42044          0
# 11401          1
# 3247           1
# 8671           1
# 51799          1
# ...          ...
# 38945          1
# 50086          1
# 47866          1
# 35553          0
# 15583          1
#
# [32076 rows x 8 columns]

# %% [markdown]
# ### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# Split data into training and validation sets
X_train, X_test, y_train, y_test = train_test_split(df["Reviews"], df["Sentiment"],
                                                   test_size=0.35, random_state=50)

print('Loaded %d training examples and %d validation examples.\n' % (X_train.shape[0], X_test.shape[0]))

# Print a sample review from the training set
print('Sample review in the training set:\n', X_train.iloc[0])  # Use iloc to access by positional index

# Example of iterating through first few reviews in training set
print('\nFirst few reviews in the training set:')
for i in range(5):
    print(f'Review {i+1}: {X_train.iloc[i]}')
# Out:
# Loaded 20849 training examples and 11227 validation examples.
#
# Sample review in the training set:
#  “The” CPU if you want performance with no compromises, it worth every penny it cost. Make sure you couple it with an adequate cooling system. Among the best solution money can buy at this moment.
#
# First few reviews in the training set:
# Review 1: “The” CPU if you want performance with no compromises, it worth every penny it cost. Make sure you couple it with an adequate cooling system. Among the best solution money can buy at this moment.
# Review 2: Ordered a cpu just to find out it was damaged and slot 3 and 4 did not work on motherboard due to cpu. After I was told I would be refunded I was only refunded 1pence instead of the full amount.
# Review 3: Bios updated to the latest as of late March. CPU would not run normally on manually tuned Intel settings. Even dropping the speeds to well be low stock and trying multiple voltage and other power settings the CPU was not stable. It's going to take three weeks for a refund. No replacement option offered.
# Review 4: Paired this with 32gb corsair dominator DDR5 @5800mhz , asus prime A , and a 3070ti on windows 11 and I'm having a really smooth experience. Games run flawlessly and much smoother than my 10900k, went into Bios and unlocked the 65w limit and away you go. The cpu stays cool (under lian li galahad 240). Really can't fault it in anyway.
# Review 5: I bought this CPU to upgrade my 2017 iMac from a i5 3.8 to the I7 7700K 4.2.... Worked like a charm! Ordered it and got it fast.  Just finished the upgrade and can definitely tell a huge difference in speed. I was a little nervous about buying a used CPU but so far so good. Ill try and update down the road to let you know how its still performing. Overall very pleased.

# %%
# Load your data (df["Reviews"] and df["Sentiment"])

# Define the undersampling method (RandomUnderSampler)
rus = RandomUnderSampler(random_state=50)

# Undersample while preserving data types (using Series.to_frame)
X_resampled_df = pd.DataFrame(df["Reviews"].values.reshape(-1, 1), columns=["Reviews"])
y_resampled_df = pd.Series(df["Sentiment"])
X_resampled, y_resampled = rus.fit_resample(X_resampled_df, y_resampled_df)

# Convert back to pandas Series after undersampling (assuming text in "Reviews")
X_resampled = pd.Series(X_resampled.squeeze())  # Assuming text data in first column

# Split the undersampled data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled,
                                                    test_size=0.35, random_state=50)

# Print class distribution after undersampling
print('Class distribution after undersampling:')
print(y_train.value_counts())  # Print counts for each sentiment class

print('Loaded %d training examples and %d validation examples.\n' % (X_train.shape[0], X_test.shape[0]))
# Out:
# Class distribution after undersampling:
# Sentiment
# 0    2943
# 1    2897
# Name: count, dtype: int64
# Loaded 5840 training examples and 3146 validation examples.

# %% [markdown]
# ---
# <a id="part3"></a>
# ## Part 3. Bag of Words

# %% [markdown]
# The goal of this project is to classify the reviews into positive and negative sentiment. There are two main steps involved. First, we need to find a word embedding to convert a text into a numerical representation. Second, we fit the numerical representations of text to machine learning algorithms or deep learning architectures.
#
# One common approach of word embedding is frequency based embedding such as Bag of Words (BoW) model. BoW model learns a vocubulary list from a given corpus and represents each document based on some counting methods of words. In this part, we will explore the model performance of using BoW with supervised learning algorithms. Here's the workflow in this part.
#
# * Step 1 : Preprocess raw reviews to cleaned reviews
# * Step 2 : Create BoW using CountVectorizer / Tfidfvectorizer in sklearn
# * Step 3 : Transform review text to numerical representations (feature vectors)
# * Step 4 : Fit feature vectors to supervised learning algorithm (eg. Naive Bayes, Logistic regression, etc.)
# * Step 5 : Improve the model performance by GridSearch

# %% [markdown]
# ### Text Preprocessing

# %% [markdown]
# The following text preprocessing are implemented to convert raw reviews to cleaned review, so that it will be easier for us to do feature extraction in the next step.
# * remove html tags using BeautifulSoup
# * remove non-character such as digits and symbols
# * convert to lower case
# * remove stop words such as "the" and "and" if needed
# * convert to root words by stemming if needed

# %%
def cleanText(raw_text, remove_stopwords=False, stemming=False, split_text=False, \
             ):
    '''
    Convert a raw review to a cleaned review
    '''
    text = BeautifulSoup(raw_text, 'lxml').get_text()  #remove html
    letters_only = re.sub("[^a-zA-Z]", " ", text)  # remove non-character
    words = letters_only.lower().split() # convert to lower case 
    
    if remove_stopwords: # remove stopword
        stops = set(stopwords.words("english"))
        words = [w for w in words if not w in stops]
        
    if stemming==True: # stemming
#         stemmer = PorterStemmer()
        stemmer = SnowballStemmer('english') 
        words = [stemmer.stem(w) for w in words]
        
    if split_text==True:  # split text
        return (words)
    
    return( " ".join(words))

# %%
from bs4 import BeautifulSoup
import numpy as np

# Assuming X_train and X_test are lists of text data
# Define a function to clean text data

# Preprocess text data in training set and validation set
X_train_cleaned = []
X_test_cleaned = []

for d in X_train:
    X_train_cleaned.append(cleanText(d))
print('Show a cleaned review in the training set : \n')
for i in range(5):
    print(X_train_cleaned[i])
    
for d in X_test:
    X_test_cleaned.append(cleanText(d))
# Out:
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\179031280.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(raw_text, 'lxml').get_text()  #remove html
# Show a cleaned review in the training set :
#
# item arrived faster than promised and in great shape no issues installing or using bulk packaging if that s important to you but not for me terrific item
# this is as a good processor but this processor requires separate graphics card without graphics card there will be no display
# works just fine really fast lots of cores with all the cores running they will run up to c and throttle back on clock speed with pretty much any standard cpu cooler the consensus seems to be that this is limited by the thermal connection inside the cpu case between the actual chip and the upper surface which contacts your cooling block in other words the cores can overheat even if your cooling system can maintain the upper surface of the cpu at room temperature you don t want the cores running hot at c for any length of time and so you really need to tune the cpu clock speed and the voltages with a motherboard that permits overclock tuning with a good standard cpu cooler i found it s possible to run continuously with a ghz clock on all cores and keep the core temperatures below c
# maine i th gen f order kiya tha lekin aya f my money loss return policy kam nahi kar raha hai
# used it on a z msi ace max it was very unstable insta crash while trying to run cinebench r crashing while gaming i reached intel support and after some tweakings they ended up recommending to return it to amazon as it was less than days i had the cpu i m not trying this one anymore

# %% [markdown]
# ### CountVectorizer with Mulinomial Naive Bayes (Benchmark Model)

# %% [markdown]
# Now we have cleaned reviews, the next step is to convert the reviews into numerical representations for machine learning algorithm.
#
# In sklearn library, we can use CountVectorizer which implements both tokenization and occurrence counting in a single class. The output is a sparse matrix representation of a document.

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Fit and transform the training data to a document-term matrix using CountVectorizer
countVect = CountVectorizer() 
X_train_countVect = countVect.fit_transform(X_train_cleaned)
print("Number of features : %d \n" % len(countVect.get_feature_names_out())) #6378 
print("Show some feature names : \n", countVect.get_feature_names_out()[1::1000])

# Train MultinomialNB classifier
mnb = MultinomialNB()
mnb.fit(X_train_countVect, y_train)
# Out:
# Number of features : 2191
#
# Show some feature names :
#  ['ability' 'latest' 'un']
# MultinomialNB()

# %%
def modelEvaluation(predictions):
    '''
    Print model evaluation to predicted result 
    '''
    print ("\nAccuracy on validation set: {:.4f}".format(accuracy_score(y_test, predictions)))
    print("\nAUC score : {:.4f}".format(roc_auc_score(y_test, predictions)))
    print("\nClassification report : \n", metrics.classification_report(y_test, predictions))
    print("\nConfusion Matrix : \n", metrics.confusion_matrix(y_test, predictions))

# %%
# Evaluate the model on validaton set
X_test_features = countVect.transform(X_test_cleaned) 
predictions = mnb.predict(X_test_features)
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 0.9762
#
# AUC score : 0.9762
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98      1550
#            1       0.98      0.97      0.98      1596
#
#     accuracy                           0.98      3146
#    macro avg       0.98      0.98      0.98      3146
# weighted avg       0.98      0.98      0.98      3146
#
#
# Confusion Matrix :
#  [[1522   28]
#  [  47 1549]]

# %% [markdown]
# ### TfidfVectorizer with Logistic Regression

# %% [markdown]
# Some words might frequently appear but have little meaningful information about the sentiment of a particular review. Instead of using occurance counting, we can use tf-idf transform to scale down the impact of frequently appeared words in a given corpus.
#
# In sklearn library, we can use TfidfVectorizer which implements both tokenization and tf-idf weighted counting in a single class.

# %%
# Fit and transform the training data to a document-term matrix using TfidfVectorizer 
tfidf = TfidfVectorizer(min_df=5) #minimum document frequency of 5
X_train_tfidf = tfidf.fit_transform(X_train)
print("Number of features : %d \n" %len(tfidf.get_feature_names_out())) #1722
print("Show some feature names : \n", tfidf.get_feature_names_out()[1::1000])

# Logistic Regression
lr = LogisticRegression()
lr.fit(X_train_tfidf, y_train)
# Out:
# Number of features : 2186
#
# Show some feature names :
#  ['0ghz' 'hence' 'true']
# LogisticRegression()

# %%
# Look at the top 10 features with smallest and the largest coefficients
feature_names = np.array(tfidf.get_feature_names_out())
sorted_coef_index = lr.coef_[0].argsort()
print('\nTop 10 features with smallest coefficients :\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Top 10 features with largest coefficients : \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
# Out:
# Top 10 features with smallest coefficients :
# ['broken' 'overheating' 'ryzen' 'was' 'received' 'it' 'different' 'not'
#  'apart' 'don']
#
# Top 10 features with largest coefficients :
# ['for' 'great' 'good' 'my' 'which' 'best' 'fast' 'need' 'have' 'i5']

# %%
# Evaluate on the validaton set
predictions = lr.predict(tfidf.transform(X_test_cleaned))
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 0.9987
#
# AUC score : 0.9987
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1550
#            1       1.00      1.00      1.00      1596
#
#     accuracy                           1.00      3146
#    macro avg       1.00      1.00      1.00      3146
# weighted avg       1.00      1.00      1.00      3146
#
#
# Confusion Matrix :
#  [[1547    3]
#  [   1 1595]]

# %% [markdown]
# ### Pipeline and GridSearch

# %% [markdown]
# In sklearn library, we can build a pipeline to streamline the workflow and use GridSearch on the pipeline model to implement hyper-parameter tuning for both vectorizer and classifier in one go.

# %%
# Building a pipeline
estimators = [("tfidf", TfidfVectorizer()), ("lr", LogisticRegression())]
model = Pipeline(estimators)


# Grid search
params = {"lr__C":[0.2, 1, 10], #regularization param of logistic regression
          "tfidf__min_df": [1, 10], #min count of words 
          "tfidf__max_features": [1000, None], #max features
          "tfidf__ngram_range": [(1,1), (1,2)], #1-grams or 2-grams
          "tfidf__stop_words": [None, "english"]} #use stopwords or don't

grid = GridSearchCV(estimator=model, param_grid=params, scoring="accuracy", n_jobs=-1)
grid.fit(X_train_cleaned, y_train)
print("The best paramenter set is : \n", grid.best_params_)


# Evaluate on the validaton set
predictions = grid.predict(X_test_cleaned)
modelEvaluation(predictions)
# Out:
# The best paramenter set is :
#  {'lr__C': 10, 'tfidf__max_features': 1000, 'tfidf__min_df': 1, 'tfidf__ngram_range': (1, 1), 'tfidf__stop_words': None}
#
# Accuracy on validation set: 1.0000
#
# AUC score : 1.0000
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1550
#            1       1.00      1.00      1.00      1596
#
#     accuracy                           1.00      3146
#    macro avg       1.00      1.00      1.00      3146
# weighted avg       1.00      1.00      1.00      3146
#
#
# Confusion Matrix :
#  [[1550    0]
#  [   0 1596]]

# %% [markdown]
# ---
# <a id="part4"></a>
# ## Part 4. Word2Vec

# %% [markdown]
# Another common approach of word embedding is prediction based embedding, such as Word2Vec model. In gist, Word2Vec is a combination of two techniques: Continuous Bag of Words (CBoW) and skip-gram model. Both are shallow neural networks which learn weights for word vector representations.
#
# In this part, we will train Word2Vec model to create our own word vector representations using gensim library. Then we fit the feature vectors of the reviews to Random Forest Classifier. Here's the workflow of this part.
#
# * Step 1 : Parse review text to sentences (Word2Vec model takes a list of sentences as inputs)
# * Step 2 : Create volcabulary list using Word2Vec model
# * Step 3 : Transform each review into numerical representation by computing average feature vectors of words therein
# * Step 4 : Fit the average feature vectors to Random Forest Classifier

# %% [markdown]
# ### Parsing Review into Sentences

# %% [markdown]
# Word2Vec model takes a list of sentences as inputs and outputs word vector representations for words in the vocalbulary list created. Before we train the Word2Vec model, we have to parse reviews in the training set into sentences.

# %%
from nltk.tokenize import word_tokenize
from nltk.tokenize.punkt import PunktSentenceTokenizer
import nltk
nltk.download('punkt')

# Define the tokenizer
tokenizer = PunktSentenceTokenizer()

def parseSent(review, tokenizer, remove_stopwords=False):
    '''
    Parse text into sentences
    '''
    raw_sentences = tokenizer.tokenize(review.strip())
    sentences = []
    for raw_sentence in raw_sentences:
        if len(raw_sentence) > 0:
            sentences.append(word_tokenize(cleanText(raw_sentence, remove_stopwords)))
    return sentences

# Parse each review in the training set into sentences
sentences = []
for review in X_train_cleaned:
    sentences += parseSent(review, tokenizer)

print('%d parsed sentences in the training set\n' % len(sentences))
print("Some parsed sentences from the training set:")
for i in range(5):  # Adjust the range as needed
    print(f"Sentence {i+1}: {sentences[i]}")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\garvb\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# 5840 parsed sentences in the training set
#
# Some parsed sentences from the training set:
# Sentence 1: ['item', 'arrived', 'faster', 'than', 'promised', 'and', 'in', 'great', 'shape', 'no', 'issues', 'installing', 'or', 'using', 'bulk', 'packaging', 'if', 'that', 's', 'important', 'to', 'you', 'but', 'not', 'for', 'me', 'terrific', 'item']
# Sentence 2: ['this', 'is', 'as', 'a', 'good', 'processor', 'but', 'this', 'processor', 'requires', 'separate', 'graphics', 'card', 'without', 'graphics', 'card', 'there', 'will', 'be', 'no', 'display']
# Sentence 3: ['works', 'just', 'fine', 'really', 'fast', 'lots', 'of', 'cores', 'with', 'all', 'the', 'cores', 'running', 'they', 'will', 'run', 'up', 'to', 'c', 'and', 'throttle', 'back', 'on', 'clock', 'speed', 'with', 'pretty', 'much', 'any', 'standard', 'cpu', 'cooler', 'the', 'consensus', 'seems', 'to', 'be', 'that', 'this', 'is', 'limited', 'by', 'the', 'thermal', 'connection', 'inside', 'the', 'cpu', 'case', 'between', 'the', 'actual', 'chip', 'and', 'the', 'upper', 'surface', 'which', 'contacts', 'your', 'cooling', 'block', 'in', 'other', 'words', 'the', 'cores', 'can', 'overheat', 'even', 'if', 'your', 'cooling', 'system', 'can', 'maintain', 'the', 'upper', 'surface', 'of', 'the', 'cpu', 'at', 'room', 'temperature', 'you', 'don', 't', 'want', 'the', 'cores', 'running', 'hot', 'at', 'c', 'for', 'any', 'length', 'of', 'time', 'and', 'so', 'you', 'really', 'need', 'to', 'tune', 'the', 'cpu', 'clock', 'speed', 'and', 'the', 'voltages', 'with', 'a', 'motherboard', 'that', 'permits', 'overclock', 'tuning', 'with', 'a', 'good', 'standard', 'cpu', 'cooler', 'i', 'found', 'it', 's', 'possible', 'to', 'run', 'continuously', 'with', 'a', 'ghz', 'clock', 'on', 'all', 'cores', 'and', 'keep', 'the', 'core', 'temperatures', 'below', 'c']
# Sentence 4: ['maine', 'i', 'th', 'gen', 'f', 'order', 'kiya', 'tha', 'lekin', 'aya', 'f', 'my', 'money', 'loss', 'return', 'policy', 'kam', 'nahi', 'kar', 'raha', 'hai']
# Sentence 5: ['used', 'it', 'on', 'a', 'z', 'msi', 'ace', 'max', 'it', 'was', 'very', 'unstable', 'insta', 'crash', 'while', 'trying', 'to', 'run', 'cinebench', 'r', 'crashing', 'while', 'gaming', 'i', 'reached', 'intel', 'support', 'and', 'after', 'some', 'tweakings', 'they', 'ended', 'up', 'recommending', 'to', 'return', 'it', 'to', 'amazon', 'as', 'it', 'was', 'less', 'than', 'days', 'i', 'had', 'the', 'cpu', 'i', 'm', 'not', 'trying', 'this', 'one', 'anymore']

# %% [markdown]
# ### Creating Volcabulary List using Word2Vec Model

# %% [markdown]
# Now we have a set of cleaned and parsed sentences from the training data, we can train our own word vector representations by sepcifiying the embedding dimension (= length of feature vector).

# %%
import logging
import re
from gensim.models import Word2Vec

# Enable logging for gensim
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

num_features = 300  # Embedding dimension
min_word_count = 10  # Minimum word count
num_workers = 4  # Number of threads to run in parallel
context = 10  # Context window size
downsampling = 1e-3  # Downsample setting for frequent words
epochs = 3  # Number of epochs

print("Training Word2Vec model ...\n")

# Assume `sentences` is your list of tokenized sentences
w2v = Word2Vec(sentences=sentences,vector_size=num_features, min_count=min_word_count, workers=num_workers,
               window=context, sample=downsampling)

w2v.build_vocab(sentences)

# Train the model
w2v.train(sentences, total_examples=w2v.corpus_count, epochs=epochs)

# To make the model memory-efficient
w2v.init_sims(replace=True)

# Save the model
w2v.save("w2v_300features_10minwordcounts_10context")

# Access vocabulary information (avoiding deprecated 'vocab' attribute)
all_words = list(w2v.wv.key_to_index.keys())  # Get all words using key_to_index

# Remove punctuation and other symbols
cleaned_vocabulary = [word for word in all_words if re.match(r'^\w+$', word)]

print("Number of words in the cleaned vocabulary list: %d \n" % len(cleaned_vocabulary))
print("Show words in the cleaned vocabulary list: \n", cleaned_vocabulary)
# Out:
# 2024-07-04 11:14:52,278 : INFO : collecting all words and their counts
# 2024-07-04 11:14:52,279 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-07-04 11:14:52,308 : INFO : collected 2211 word types from a corpus of 198992 raw words and 5840 sentences
# Training Word2Vec model ...
# 2024-07-04 11:14:52,308 : INFO : Creating a fresh vocabulary
# 2024-07-04 11:14:52,314 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 1480 unique words (66.94% of original 2211, drops 731)', 'datetime': '2024-07-04T11:14:52.314952', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:52,316 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 195303 word corpus (98.15% of original 198992, drops 3689)', 'datetime': '2024-07-04T11:14:52.316468', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:52,323 : INFO : deleting the raw counts dictionary of 2211 items
# 2024-07-04 11:14:52,325 : INFO : sample=0.001 downsamples 70 most-common words
# 2024-07-04 11:14:52,327 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 140519.50056353275 word corpus (71.9%% of prior 195303)', 'datetime': '2024-07-04T11:14:52.327540', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:52,340 : INFO : estimated required memory for 1480 words and 300 dimensions: 4292000 bytes
# 2024-07-04 11:14:52,341 : INFO : resetting layer weights
# 2024-07-04 11:14:52,346 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-07-04T11:14:52.346457', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-07-04 11:14:52,347 : INFO : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 1480 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-07-04T11:14:52.347480', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-07-04 11:14:52,465 : INFO : EPOCH 0: training on 198992 raw words (140444 effective words) took 0.1s, 1248499 effective words/s
# 2024-07-04 11:14:52,589 : INFO : EPOCH 1: training on 198992 raw words (140339 effective words) took 0.1s, 1189753 effective words/s
# 2024-07-04 11:14:52,703 : INFO : EPOCH 2: training on 198992 raw words (140572 effective words) took 0.1s, 1348714 effective words/s
# 2024-07-04 11:14:52,828 : INFO : EPOCH 3: training on 198992 raw words (140479 effective words) took 0.1s, 1188158 effective words/s
# 2024-07-04 11:14:52,948 : INFO : EPOCH 4: training on 198992 raw words (140604 effective words) took 0.1s, 1230895 effective words/s
# 2024-07-04 11:14:52,950 : INFO : Word2Vec lifecycle event {'msg': 'training on 994960 raw words (702438 effective words) took 0.6s, 1166978 effective words/s', 'datetime': '2024-07-04T11:14:52.949682', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-07-04 11:14:52,951 : INFO : Word2Vec lifecycle event {'params': 'Word2Vec<vocab=1480, vector_size=300, alpha=0.025>', 'datetime': '2024-07-04T11:14:52.950682', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'created'}
# 2024-07-04 11:14:52,951 : INFO : collecting all words and their counts
# 2024-07-04 11:14:52,952 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2024-07-04 11:14:52,981 : INFO : collected 2211 word types from a corpus of 198992 raw words and 5840 sentences
# 2024-07-04 11:14:52,982 : INFO : Creating a fresh vocabulary
# 2024-07-04 11:14:52,990 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 retains 1480 unique words (66.94% of original 2211, drops 731)', 'datetime': '2024-07-04T11:14:52.990431', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:52,991 : INFO : Word2Vec lifecycle event {'msg': 'effective_min_count=10 leaves 195303 word corpus (98.15% of original 198992, drops 3689)', 'datetime': '2024-07-04T11:14:52.991429', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:53,003 : INFO : deleting the raw counts dictionary of 2211 items
# 2024-07-04 11:14:53,004 : INFO : sample=0.001 downsamples 70 most-common words
# 2024-07-04 11:14:53,004 : INFO : Word2Vec lifecycle event {'msg': 'downsampling leaves estimated 140519.50056353275 word corpus (71.9%% of prior 195303)', 'datetime': '2024-07-04T11:14:53.004461', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'prepare_vocab'}
# 2024-07-04 11:14:53,005 : WARNING : sorting after vectors have been allocated is expensive & error-prone
# 2024-07-04 11:14:53,015 : INFO : estimated required memory for 1480 words and 300 dimensions: 4292000 bytes
# 2024-07-04 11:14:53,016 : INFO : resetting layer weights
# 2024-07-04 11:14:53,018 : INFO : Word2Vec lifecycle event {'update': False, 'trim_rule': 'None', 'datetime': '2024-07-04T11:14:53.018168', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'build_vocab'}
# 2024-07-04 11:14:53,018 : WARNING : Effective 'alpha' higher than previous training cycles
# 2024-07-04 11:14:53,018 : INFO : Word2Vec lifecycle event {'msg': 'training model with 4 workers on 1480 vocabulary and 300 features, using sg=0 hs=0 sample=0.001 negative=5 window=10 shrink_windows=True', 'datetime': '2024-07-04T11:14:53.018678', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# 2024-07-04 11:14:53,150 : INFO : EPOCH 0: training on 198992 raw words (140541 effective words) took 0.1s, 1126759 effective words/s
# 2024-07-04 11:14:53,271 : INFO : EPOCH 1: training on 198992 raw words (140297 effective words) took 0.1s, 1226889 effective words/s
# 2024-07-04 11:14:53,387 : INFO : EPOCH 2: training on 198992 raw words (140297 effective words) took 0.1s, 1262152 effective words/s
# 2024-07-04 11:14:53,388 : INFO : Word2Vec lifecycle event {'msg': 'training on 596976 raw words (421135 effective words) took 0.4s, 1142161 effective words/s', 'datetime': '2024-07-04T11:14:53.388673', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'train'}
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\3594573010.py:27: DeprecationWarning: Call to deprecated `init_sims` (Gensim 4.0.0 implemented internal optimizations that make calls to init_sims() unnecessary. init_sims() is now obsoleted and will be completely removed in future versions. See https://github.com/RaRe-Technologies/gensim/wiki/Migrating-from-Gensim-3.x-to-4).
#   w2v.init_sims(replace=True)
# 2024-07-04 11:14:53,392 : WARNING : destructive init_sims(replace=True) deprecated & no longer required for space-efficiency
# 2024-07-04 11:14:53,394 : INFO : Word2Vec lifecycle event {'fname_or_handle': 'w2v_300features_10minwordcounts_10context', 'separately': 'None', 'sep_limit': 10485760, 'ignore': frozenset(), 'datetime': '2024-07-04T11:14:53.394678', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'saving'}
# 2024-07-04 11:14:53,394 : INFO : not storing attribute cum_table
# 2024-07-04 11:14:53,399 : INFO : saved w2v_300features_10minwordcounts_10context
# Number of words in the cleaned vocabulary list: 1480
#
# Show words in the cleaned vocabulary list:
#  ['i', 'the', 'it', 'and', 'a', 'this', 'to', 'with', 'is', 'was', 'for', 'cpu', 'of', 'processor', 'in', 'not', 'but', 't', 'so', 'on', 's', 'my', 'you', 'at', 'that', 'good', 'no', 'from', 'intel', 'as', 'price', 'if', 'have', 'can', 'k', 'product', 'are', 'cooler', 'gen', 'had', 'core', 'gaming', 'box', 'get', 'performance', 'fine', 'better', 'stock', 'amazon', 'or', 'be', 'than', 'will', 'don', 'very', 'one', 'graphics', 'only', 'works', 'broken', 'working', 'fan', 'm', 'up', 'any', 'an', 'like', 'there', 'run', 'even', 'more', 'buy', 'low', 'got', 'just', 'pc', 'would', 'used', 'motherboard', 'all', 'after', 'while', 'cores', 'what', 'ryzen', 'when', 'time', 'chip', 'same', 'bought', 'great', 'card', 'work', 'new', 'th', 'am', 'they', 'return', 'me', 'f', 'well', 'power', 'difference', 'money', 'use', 'computer', 'its', 'games', 'upgrade', 'mhz', 'go', 'didn', 'trying', 'c', 'now', 'some', 'has', 'need', 'less', 'pricing', 'x', 'do', 'item', 'really', 'settings', 'because', 'packaging', 'days', 'fast', 'ghz', 'u', 'your', 'received', 'out', 'real', 'amd', 'heatsink', 'r', 'heat', 'avoid', 'z', 'does', 'around', 'end', 'cause', 'life', 'best', 'performence', 'touching', 'over', 'instead', 'ddr', 'thermal', 'high', 'liked', 'replace', 'without', 'which', 'say', 'king', 'oversized', 'here', 'stable', 'doesn', 'being', 'issue', 'air', 'blade', 'getting', 'small', 'parts', 'game', 'far', 'we', 'desktop', 'many', 'na', 'value', 'processors', 've', 'graphic', 'happy', 'ram', 'gon', 'cardboard', 'video', 'rather', 'anti', 'static', 'may', 'delivery', 'case', 'too', 'gb', 'other', 'old', 'p', 'msi', 'cinebench', 'using', 'been', 'photo', 'paste', 'nice', 'e', 'bios', 'max', 'dont', 'refund', 'build', 'thought', 'find', 'expected', 'back', 'people', 'much', 'ks', 'purchased', 'want', 'seal', 'support', 'playing', 'first', 'information', 'open', 'runs', 'love', 'anything', 'know', 'speeds', 'replaced', 'came', 'fps', 'itself', 'speed', 'worst', 'replacement', 'should', 'gpu', 'running', 'most', 'unstable', 'editing', 'paired', 'give', 'cost', 'worth', 'upgraded', 'going', 'already', 'see', 'model', 'damaged', 'take', 'comes', 'put', 'once', 'sink', 'these', 'market', 'apart', 'by', 'faulty', 'weeks', 'asus', 'retail', 'point', 'latest', 'budget', 'think', 'd', 'another', 'perfectly', 'dedicated', 'never', 'annoying', 'expensive', 'able', 'why', 'looks', 'option', 'efficiency', 'tasks', 'updated', 'experiencing', 'crashes', 'consuming', 'stressful', 'moments', 'into', 'cant', 'shipped', 'then', 'wrapped', 'also', 'different', 'enough', 'please', 'crashing', 'voltage', 'launch', 'ended', 'crappy', 'looking', 'delivered', 'b', 'about', 'full', 'ace', 'uplift', 'ur', 'anymore', 'returning', 'unboxed', 'since', 'how', 'nas', 'fit', 'original', 'described', 'super', 'amazing', 'multiple', 'did', 'packing', 'ordered', 'thing', 'raise', 'aio', 'buying', 'hot', 'look', 'insta', 'reached', 'w', 'noise', 'recommending', 'tweakings', 'crash', 'last', 'found', 'come', 'else', 'seller', 'name', 'normally', 'dropping', 'late', 'tuned', 'three', 'offered', 'manually', 'march', 'properly', 'still', 'creating', 'critical', 'deepcool', 'virbration', 'refunded', 'cooling', 'hangs', 'system', 'advertised', 'cool', 'extra', 'send', 'cover', 'hard', 'series', 'appario', 'beast', 'awful', 'blades', 'board', 'review', 'seems', 'applications', 'gtx', 'etc', 'who', 'rendering', 'went', 'ti', 'higher', 'load', 'easily', 'maybe', 'recommend', 'usage', 'smooth', 'inside', 'threads', 'sale', 'xe', 'packaged', 'acceptable', 'reyzen', 'won', 'having', 'gamer', 'hai', 'job', 'display', 'overheating', 'perfect', 'contact', 'everything', 'computing', 'way', 'short', 'otherwise', 'll', 'pay', 'certainly', 'consumption', 'he', 'wrap', 'actual', 'bubble', 'order', 'inr', 'unlocked', 'however', 'black', 'room', 'costs', 'spend', 'wait', 'needs', 'clock', 'ssd', 'top', 'lot', 'version', 'rattling', 'shell', 'lightly', 'excellent', 'paid', 'listed', 'bag', 'mm', 'clam', 'ta ...

# %% [markdown]
# ### Averaging Feature Vectors

# %% [markdown]
# Now we have created a volcabulary list of words, with each word having a word representation (ie. feature vector of dim 300).
#
# To find a numerical representation for a review, we run through each word in a review text. For words appear in the volcabulary list, we compute the average feature vectors of all those words. The average feature vector is the numerical represenation of the review.

# %%
# Transfrom the training data into feature vectors

def makeFeatureVec(review, model, num_features):
  """
  Transforms a review into a feature vector by averaging word vectors.

  Args:
      review (list): List of words in the review.
      model (gensim.models.Word2Vec): The trained Word2Vec model.
      num_features (int): Dimensionality of the word vectors.

  Returns:
      numpy.ndarray: Feature vector representing the review (shape: (num_features,)).
  """

  feature_vec = np.zeros((num_features,), dtype="float32")
  word_count = 0

  # Iterate through words in the review, checking for existence and adding vectors
  for word in review:
    if word in model.wv.key_to_index:  # Check if word exists in vocabulary
      word_count += 1
      feature_vec = np.add(feature_vec, model.wv[word])  # Use model.wv for word vectors

  # Handle cases with no words in vocabulary (return zero vector)
  if word_count == 0:
    return feature_vec

  # Average the feature vector (divide by word count)
  return np.divide(feature_vec, word_count)


def getAvgFeatureVecs(reviews, model, num_features):
  """
  Transforms all reviews in a list into feature vectors using makeFeatureVec.

  Args:
      reviews (list): List of reviews (each review is a list of words).
      model (gensim.models.Word2Vec): The trained Word2Vec model.
      num_features (int): Dimensionality of the word vectors.

  Returns:
      numpy.ndarray: Feature vectors for all reviews (shape: (len(reviews), num_features)).
  """

  review_feature_vecs = np.zeros((len(reviews), num_features), dtype="float32")
  for i, review in enumerate(reviews):
    review_feature_vecs[i] = makeFeatureVec(review, model, num_features)

  return review_feature_vecs

# %%
X_train_cleaned = []
for review in X_train:
    X_train_cleaned.append(cleanText(review, remove_stopwords=True))
trainVector = getAvgFeatureVecs(X_train_cleaned, w2v, num_features)
print("Training set : %d feature vectors with %d dimensions" % trainVector.shape)

# Get feature vectors for validation set
X_test_cleaned = []
for review in X_test:
    X_test_cleaned.append(cleanText(review, remove_stopwords=True))
testVector = getAvgFeatureVecs(X_test_cleaned, w2v, num_features)
print("Validation set : %d feature vectors with %d dimensions" % testVector.shape)
# Out:
# C:\Users\garvb\AppData\Local\Temp\ipykernel_11404\179031280.py:6: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   text = BeautifulSoup(raw_text, 'lxml').get_text()  #remove html
# Training set : 5840 feature vectors with 300 dimensions
# Validation set : 3146 feature vectors with 300 dimensions

# %% [markdown]
# ### Random Forest Classifer

# %% [markdown]
# We can now train Random Forest Classifier using feature vectors of reviews in the training set.

# %%
# Random Forest Classifier
rf = RandomForestClassifier(n_estimators=100, max_depth=7)
rf.fit(trainVector, y_train)
predictions = rf.predict(testVector)
modelEvaluation(predictions)
# Out:
# Accuracy on validation set: 1.0000
#
# AUC score : 1.0000
#
# Classification report :
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1550
#            1       1.00      1.00      1.00      1596
#
#     accuracy                           1.00      3146
#    macro avg       1.00      1.00      1.00      3146
# weighted avg       1.00      1.00      1.00      3146
#
#
# Confusion Matrix :
#  [[1550    0]
#  [   0 1596]]

# %%
# Feature importance based on RandomForestClassifier
feature_importance = rf.feature_importances_

# Get feature names (assuming df is a pandas DataFrame)
feature_names = df.columns

# Sort feature importance in descending order
sorted_idx = np.argsort(feature_importance)[::-1]

# Print feature importance ranking
print("Feature importance ranking:")
for i in sorted_idx:
    if i < len(feature_names):  # Ensure index is within bounds
        print(f"{feature_names[i]}: {feature_importance[i]}")
# Out:
# Feature importance ranking:
# Rating: 0.0048004694608103585
# Sentiment: 0.0039010475789431225
# Reviews: 0.0035509642773072897
# Core_Series: 0.00354286557140677
# Generation: 0.002977479351323441
# Location: 0.0026414447865470525
# Model: 0.00220012007192202
# Date: 0.00149101976316986

# %% [markdown]
# ---
# <a id="part5"></a>
# ## Part 5. LSTM

# %% [markdown]
# Long Short Term Memory networks (LSTM) are a special kind of Recurrent Neural Networks (RNN), capable of learning long-term dependencies. LSTM can be very usefull in text mining problems since it involves dependencies in the sentences which can be caught in the "memory" of the LSTM.
#
# In this part, we train a simple LSTM and a LSTM with Word2Vec embedding to classify the reviews into positive and negative  sentiment using Keras libarary.

# %% [markdown]
# ### Simple LSTM

# %% [markdown]
# We need to preprocess the text data to 2D tensor before we fit into a simple LSTM. First, we tokenize the corpus by only considering top words (top_words = 20000), and transform reviews to numerical sequences using the trained tokenizer. Next, we make sure that all numerical sequences have the same length (maxlen=100) for modeling, by truncating long reviews and pad shorter reviews with zero values.
#
# To construct a simple LSTM, we use embedding class in Keras to construct the first layer. This embedding layer converts numerical sequence of words into a word embedding. We should note that the embedding class provides a convenient way to map discrete words into a continuous vector space, but it does not take the semantic similarity of the words into account. The next layer is the LSTM layer with 128 memory units. Finally, we use a dense output layer with a single neuron and a sigmoid activation function to make 0 or 1 predictions for the two classes (positive sentiment and negative sentiment). Since it is a binary classification problem, log loss is used as the loss function (binary_crossentropy in Keras). ADAM optimization algorithm is used.
#
# Here's the workflow in this part.
# * Step 1 : Prepare X_train and X_test to 2D tensor
# * Step 2 : Train a simple LSTM (embeddign layer => LSTM layer => dense layer)
# * Step 3 : Compile and fit the model using log loss function and ADAM optimizer

# %%
top_words = 20000 
maxlen = 100 
batch_size = 32
nb_classes = 2
nb_epoch = 3


# Vectorize X_train and X_test to 2D tensor
tokenizer = Tokenizer(nb_words=top_words) #only consider top 20000 words in the corpse
tokenizer.fit_on_texts(X_train_cleaned)
# tokenizer.word_index #access word-to-index dictionary of trained tokenizer

sequences_train = tokenizer.texts_to_sequences(X_train_cleaned)
sequences_test = tokenizer.texts_to_sequences(X_test_cleaned)

X_train_seq = sequence.pad_sequences(sequences_train, maxlen=maxlen)
X_test_seq = sequence.pad_sequences(sequences_test, maxlen=maxlen)

# one-hot encoding of y_train and y_test
y_train_seq = to_categorical(y_train, nb_classes)
y_test_seq = to_categorical(y_test, nb_classes)

print('X_train shape:', X_train_seq.shape) #(27799, 100)
print('X_test shape:', X_test_seq.shape) #(3089, 100)
print('y_train shape:', y_train_seq.shape) #(27799, 2)
print('y_test shape:', y_test_seq.shape) #(3089, 2)
# Out:
# X_train shape: (5840, 100)
# X_test shape: (3146, 100)
# y_train shape: (5840, 2)
# y_test shape: (3146, 2)
# C:\Users\garvb\anaconda3\envs\Devshouse\lib\site-packages\keras\src\legacy\preprocessing\text.py:98: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn(

# %%
# Construct a simple LSTM
model1 = Sequential()
model1.add(Embedding(top_words, 128))
model1.add(Dropout(0.3))
model1.add(LSTM(64))
model1.add(Dropout(0.35))
model1.add(Dense(nb_classes))
model1.add(Activation('softmax'))
model1.summary()

# Compile LSTM
model1.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model1.fit(X_train_seq, y_train_seq, batch_size=batch_size, epochs=nb_epoch, verbose=1)

# Model evaluation
score = model1.evaluate(X_test_seq, y_test_seq, batch_size=batch_size)
print('Test loss : {:.4f}'.format(score[0]))
print('Test accuracy : {:.4f}'.format(score[1]))
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.7941 - loss: 0.4935
# Epoch 2/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9979 - loss: 0.0150
# Epoch 3/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 7s 40ms/step - accuracy: 0.9990 - loss: 0.0050
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0014
# Test loss : 0.0015
# Test accuracy : 1.0000

# %%
# get weight matrix of the embedding layer
model1.layers[0].get_weights()[0] # weight matrix of the embedding layer, word-by-dim matrix
print("Size of weight matrix in the embedding layer : ", \
      model1.layers[0].get_weights()[0].shape) #(20000, 128)

# get weight matrix of the hidden layer
print("Size of weight matrix in the hidden layer : ", \
      model1.layers[2].get_weights()[0].shape) #(128, 512)  weight dim of LSTM - w

# get weight matrix of the output layer
print("Size of weight matrix in the output layer : ", \
      model1.layers[4].get_weights()[0].shape) #(128, 2) weight dim of dense layer
# Out:
# Size of weight matrix in the embedding layer :  (20000, 128)
# Size of weight matrix in the hidden layer :  (128, 256)
# Size of weight matrix in the output layer :  (64, 2)

# %% [markdown]
# ### LSTM with Word2Vec Embedding

# %% [markdown]
# In the simple LSTM model constructed above, the embedding class in Keras comes in handy to converts numerical sequence of words into a word embedding, but it does not take the semantic similarity of the words into account.  The model assigns random weights to the embedding layer and learn the embeddings by minimizing the global error of the network.
#
# Instead of using random weights, we can use pretrained word embeddings to initialize the weight of an embedding layer. In this part, we use the Word2Vec embedding trained in Part 4 to
# intialize the weights of embedding layer in LSTM.
#
# * Step 1 : Load pretrained word embedding model
# * Step 2 : Construct embedding layer using embedding matrix as weights
# * Step 3 : Train a LSTM with Word2Vec embedding (embeddign layer => LSTM layer => dense layer)
# * Step 4 : Compile and fit the model using log loss function and ADAM optimizer

# %%
# Load trained Word2Vec model
w2v = Word2Vec.load("w2v_300features_10minwordcounts_10context")


# Get Word2Vec embedding matrix
embedding_matrix = w2v.wv.vectors  # embedding matrix, type = numpy.ndarray 
print("Shape of embedding matrix : ", embedding_matrix.shape) #(4016, 300) = (volcabulary size, embedding dimension)
# w2v.wv.syn0[0] #feature vector of the first word in the volcabulary list
# Out:
# 2024-07-04 11:15:25,500 : INFO : loading Word2Vec object from w2v_300features_10minwordcounts_10context
# 2024-07-04 11:15:25,511 : INFO : loading wv recursively from w2v_300features_10minwordcounts_10context.wv.* with mmap=None
# 2024-07-04 11:15:25,512 : INFO : setting ignored attribute cum_table to None
# 2024-07-04 11:15:25,521 : INFO : Word2Vec lifecycle event {'fname': 'w2v_300features_10minwordcounts_10context', 'datetime': '2024-07-04T11:15:25.521515', 'gensim': '4.3.2', 'python': '3.10.13 | packaged by Anaconda, Inc. | (main, Sep 11 2023, 13:24:38) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.22621-SP0', 'event': 'loaded'}
# Shape of embedding matrix :  (1480, 300)

# %%
top_words = embedding_matrix.shape[0] #4016
maxlen = 100 
batch_size = 32
nb_classes = 2
nb_epoch = 3


# Vectorize X_train and X_test to 2D tensor
tokenizer = Tokenizer(nb_words=top_words) #only consider top 20000 words in the corpse
tokenizer.fit_on_texts(X_train_cleaned)
# tokenizer.word_index #access word-to-index dictionary of trained tokenizer

sequences_train = tokenizer.texts_to_sequences(X_train_cleaned)
sequences_test = tokenizer.texts_to_sequences(X_test_cleaned)

X_train_seq = sequence.pad_sequences(sequences_train, maxlen=maxlen)
X_test_seq = sequence.pad_sequences(sequences_test, maxlen=maxlen)


# one-hot encoding of y_train and y_test
y_train_seq = to_categorical(y_train, nb_classes)
y_test_seq = to_categorical(y_test, nb_classes)

print('X_train_cleaned shape:', X_train_seq.shape) #(27799, 100)
print('X_test_cleaned shape:', X_test_seq.shape) #(3089, 100)
print('y_train shape:', y_train_seq.shape) #(27799, 2)
print('y_test shape:', y_test_seq.shape) #(3089, 2)
# Out:
# C:\Users\garvb\anaconda3\envs\Devshouse\lib\site-packages\keras\src\legacy\preprocessing\text.py:98: UserWarning: The `nb_words` argument in `Tokenizer` has been renamed `num_words`.
#   warnings.warn(
# X_train_cleaned shape: (5840, 100)
# X_test_cleaned shape: (3146, 100)
# y_train shape: (5840, 2)
# y_test shape: (3146, 2)

# %%
# Construct Word2Vec embedding layer
embedding_layer = Embedding(embedding_matrix.shape[0], #4016
                            embedding_matrix.shape[1], #300
                            weights=[embedding_matrix])


# Construct LSTM with Word2Vec embedding
model2 = Sequential()
model2.add(embedding_layer)
model2.add(Dropout(0.3))
model2.add(LSTM(64))
model2.add(Dropout(0.35))
model2.add(Dense(nb_classes))
model2.add(Activation('softmax'))
model2.summary()

# Compile model
model2.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model2.fit(X_train_seq, y_train_seq, batch_size=batch_size, epochs=nb_epoch, verbose=1)


# Model evaluation
score = model2.evaluate(X_test_seq, y_test_seq, batch_size=batch_size)
print('Test loss : {:.4f}'.format(score[0]))
print('Test accuracy : {:.4f}'.format(score[1]))
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ ?                      │       444,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 444,000 (1.69 MB)
#  Trainable params: 444,000 (1.69 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 8s 32ms/step - accuracy: 0.8397 - loss: 0.3745
# Epoch 2/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 6s 33ms/step - accuracy: 0.9986 - loss: 0.0097
# Epoch 3/3
# 183/183 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - accuracy: 1.0000 - loss: 0.0015
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 1.0000 - loss: 6.0266e-04
# Test loss : 0.0007
# Test accuracy : 1.0000

# %%
# get weight matrix of the embedding layer
print("Size of weight matrix in the embedding layer : ", \
      model2.layers[0].get_weights()[0].shape) #(20000, 128)

# get weight matrix of the hidden layer
print("Size of weight matrix in the hidden layer : ", \
      model2.layers[2].get_weights()[0].shape) #(128, 512)  weight dim of LSTM - w

# get weight matrix of the output layer
print("Size of weight matrix in the output layer : ", \
      model2.layers[4].get_weights()[0].shape) #(128, 2) weight dim of dense layer
# Out:
# Size of weight matrix in the embedding layer :  (1480, 300)
# Size of weight matrix in the hidden layer :  (300, 256)
# Size of weight matrix in the output layer :  (64, 2)

# %% [markdown]
# ---
# <a id="part6"></a>
# ## Part 6. Word Cloud

# %% [markdown]
# In this part, we create word clouds for positive sentiment reviews and negative sentiment reviews of a selected brand, to get an intuition of words frequently appear in different sentiments.

# %%
predictions = model2.predict(X_test_seq)  # Get probabilities for each sentiment class
predictions = np.argmax(predictions, axis=-1) 
# Initialize empty lists for positive and negative words
positive_words = []
negative_words = []

# Loop through reviews, predictions, and pre-trained embeddings (assuming you have them)
for review, sentiment, embedding in zip(df["Reviews"], predictions, X_test_seq):
  words = review.split()  # Split review into words
  embedding_list = embedding.tolist()  # Assuming embedding is a numpy array

  # Filter words based on predicted sentiment and embedding existence
  for word, word_embedding in zip(words, embedding_list):
    if word_embedding is not None:  # Check if embedding exists (optional)
      if sentiment == 1:  # Positive sentiment
        if word not in positive_words:  # Add unique words to list
          positive_words.append(word)
      else:  # Negative sentiment
        negative_words.append(word)

# Generate word clouds
positive_wordcloud = WordCloud(width=800, height=600).generate(" ".join(positive_words))
negative_wordcloud = WordCloud(width=800, height=600).generate(" ".join(negative_words))

# Display or save word clouds
plt.figure(figsize=(10, 6))
plt.subplot(121)
plt.imshow(positive_wordcloud)
plt.title('Positive Words')
plt.axis("off")

plt.subplot(122)
plt.imshow(negative_wordcloud)
plt.title('Negative Words')
plt.axis("off")

plt.show()
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step

# %%
import nltk
from nltk.corpus import stopwords
from nltk import pos_tag
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Download NLTK stopwords and part-of-speech tagger
nltk.download('stopwords')
nltk.download('averaged_perceptron_tagger')

def is_adjective(word):
    """Check if a word is an adjective."""
    return pos_tag([word])[0][1] == 'JJ'

def is_meaningful(word):
    """Check if a word is a meaningful non-adjective."""
    pos_tagged = pos_tag([word])[0][1]
    # Include only nouns, verbs, and adverbs
    return pos_tagged.startswith('N') or pos_tagged.startswith('V') or pos_tagged == 'RB'

# Extend stopwords with common non-characteristic words
additional_stopwords = {'cpu', 'processor', 'monitor', 'pc', 'computer', 'intel', 'core', 'generation', 'desktop', 'gen', 'i5', 'i7', 'i9', 'pentium'}
stop_words = set(stopwords.words('english')).union(additional_stopwords)

def create_word_cloud_with_top_words(sentiment, adjectives_only=True):
    df_sample = df[df['Sentiment'] == sentiment]
    df_sample = df_sample.sample(frac=0.1, random_state=0)
    
    word_cloud_collection = ''
    
    for val in df_sample['Reviews'].str.lower():
        tokens = nltk.word_tokenize(val)
        if adjectives_only:
            tokens = [word for word in tokens if word.isalpha() and word not in stop_words and is_adjective(word)]
        else:
            tokens = [word for word in tokens if word.isalpha() and word not in stop_words and is_meaningful(word)]
        word_cloud_collection += ' '.join(tokens) + ' '
    
    wordcloud = WordCloud(max_font_size=50, width=500, height=300).generate(word_cloud_collection)
    
    plt.figure(figsize=(5, 5))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    sentiment_type = 'Adjectives' if adjectives_only else 'Meaningful Non-Adjectives'
    plt.title(f'Word Cloud for {sentiment_type} - Sentiment {sentiment}')
    plt.show()
    
    # Plot top 5 words
    word_counts = Counter(word_cloud_collection.split())
    top_words = word_counts.most_common(10)
    
    words, counts = zip(*top_words)
    plt.figure(figsize=(11, 5))
    plt.bar(words, counts, color='skyblue')
    plt.title(f'Top 10 {sentiment_type} Words for Sentiment {sentiment}')
    plt.xlabel('Words')
    plt.ylabel('Counts')
    plt.show()

# Create word clouds and top words for positive (1) and negative (0) sentiments
# For Meaningful Non-Adjectives
create_word_cloud_with_top_words(1, adjectives_only=False)
create_word_cloud_with_top_words(0, adjectives_only=False)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\garvb\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\garvb\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# ---
# <a id="part7"></a>
# ## Part 7. Summary Generation

# %%
from transformers import pipeline

# %%
# Initialize the BERT summarization pipeline with the specific model
summarizer = pipeline("summarization", model="google/flan-t5-base")
# Out:
# WARNING:tensorflow:From C:\Users\garvb\anaconda3\envs\Devshouse\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# 2024-07-04 11:16:18,413 : WARNING : From C:\Users\garvb\anaconda3\envs\Devshouse\lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# Using BERT: BERT (Bidirectional Encoder Representations from Transformers) is a powerful language model that can be used for text summarization. BERT-based models have achieved state-of-the-art results in various natural language processing tasks, including text summarization.

# %%
# Get positive texts from the 'text' column in your dataset
positive_texts =  df[df['Sentiment'] == 1]['Reviews'].tolist()


# Combine all positive texts into one string
combined_text = " ".join(positive_texts)

# Split the combined text into chunks of maximum length 1024
texts = []
chunk = ""
for sentence in combined_text.split():
    if len(chunk) + len(sentence) > 1024:
        texts.append(chunk)
        chunk = ""
    chunk += sentence + " "
if chunk:
    texts.append(chunk)
summaries = []
# Generate summaries for each chunk of text
for i, text in enumerate(texts):
    if i >= 10:
        break
    print("\nSummary:")
    summary = summarizer(text, max_length=100, min_length=30, do_sample=False)
    print(summary[0]['summary_text'])
    summaries.append(summary[0]['summary_text'])
# Out:
# Summary:
# I've been a long term Intel user and I have never had problems with them. This one replaced my i7-6700K and it is noticeably faster for my daily work (mostly Office, Internet content) and gaming (COD MW3). In terms of power consumption and heat generation, I can hardly notice it since all the workload I put on it hardly heats it up more than 45C-50C.
#
# Summary:
# Great product, but overpriced. It shouldn't be above 37K. It's worth for money. However, every motherboard manufacturer is now OVER VOLTING the CPUs causing them to run hotter and be less efficient so they can pass benchmarks with slightly higher scores at the cost of cooking your CPU. Now that the 10th gen is out, this is an obsolete review.
#
# Summary:
# RTX 2080 in 4K. Works well, 36 cores are going to be useful to run several VMs. Single thread it's not much faster
#
# Summary:
# This processor works like new! Don't know if it was used or not but it came in a clamshell with fairly factory looking stuff on it
#
# Summary:
# I am rather impressed with the video capabilities of this processor, it does a great job for being on-board graphics. I would not recommend it for a gamer as being a replacement...
#
# Summary:
# Very good processor in budget, cheaper than offline market in my city. Words cannot describe the change in performance. Benchmarked paired with an EVGA Geoforce 3080 RTX Ti and score beat other rigs with same GPU but later series i7 and i9 CPUs. Idles in my rig at between 55° and 60°
#
# Summary:
# I'm using a 35 dollar air cooler on this and under full load for over 10 min I never got above 68 degrees. Solid core i5, great value for an LGA 1200 build
#
# Summary:
# This is the best processor I've ever bought. It's a great value for the money, and it's the best cpu I have ever purchased.
#
# Summary:
# It's a nice processor but the price is still high for being a previous generation of processor ... but it's still a good processor
#
# Summary:
# Install the Intel Core i5-13600K (Latest Gen) Desktop Processor on your computer. Connect the CPU to your computer via a USB 3.0 cable. Plug the power supply into your computer's power supply.

# %%
# Combine individual summaries into a single string
combined_summaries = " ".join(summaries)

# Summarize the combined summaries
final_summary = summarizer(combined_summaries, max_length=200, min_length=50, do_sample=False)
print("\nFinal Summary:")
print(final_summary[0]['summary_text'])
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (524 > 512). Running this sequence through the model will result in indexing errors
# Final Summary:
# I've been a long term Intel user and I have never had problems with them. This one replaced my i7-6700K and it is noticeably faster for my daily work (mostly Office, Internet content) and gaming (COD MW3). In terms of power consumption and heat generation, I can hardly notice it since all the workload I put on it ...

# %%
# Get positive texts from the 'text' column in your dataset
negative_texts = positive_texts = df[df['Sentiment'] == 0]['Reviews'].tolist()


# Combine all positive texts into one string
combined_text = " ".join(negative_texts)

# Split the combined text into chunks of maximum length 1024
texts = []
chunk = ""
for sentence in combined_text.split():
    if len(chunk) + len(sentence) > 1024:
        texts.append(chunk)
        chunk = ""
    chunk += sentence + " "
if chunk:
    texts.append(chunk)
summaries = []
# Generate summaries for each chunk of text
for i, text in enumerate(texts):
    if i >= 10:
        break
    print("\nSummary:")
    summary = summarizer(text, max_length=100, min_length=30, do_sample=False)
    print(summary[0]['summary_text'])
    summaries.append(summary[0]['summary_text'])
# Out:
# Summary:
# Product was installed in the computer. After working for 7-10 days it has stopped working. Now I am unable to get any information where should I approach.
#
# Summary:
# Used it on a Z790 msi ace max, it was very unstable, insta crash while trying to run cinebench r23, crashing while gaming, I reached intel support and after some tweakings they ended up recommending to return it to Amazon as it was less than 30 days I had the cpu, I'm not trying this one anymore
#
# Summary:
# Computer. After working for 7-10 days it has stopped working. Now I am unable to get any information where should I approach. I contacted supplier he say talk to Amazon
#
# Summary:
# This seems like a good CPU so far but it was packaged very poorly - the chip was literally rattling around loose inside the Amazon box.
#
# Summary:
# it was very unstable, insta crash while trying to run cinebench r23, crashing while gaming, I reached intel support and after ...
#
# Summary:
# I reached intel support and after some tweakings they ended up recommending to return it to Amazon as it was less than 30 days I had the cpu
#
# Summary:
# DO NOT BUY THIS PRODUCT. DO NOT buy this product from "Computer Upgrade King" unless you want to run a game on your NAS.
#
# Summary:
# clam-shell cover, no clam shell, no bubble wrap, no plastic clam - shell cover, clamshell, bubble wrap ...
#
# Summary:
# Don't buy anything from "Computer Upgrade King", and it was described as being the retail model of the processor with the stock heat sink. Instead it came with a crappy oversized "gaming" heatsink and...
#
# Summary:
# BIOS BIOS update to the latest as of late March. CPU would not run normally on manually tuned Intel settings. Even dropping br>

# %%
# Combine individual summaries into a single string
combined_summaries = " ".join(summaries)

# Summarize the combined summaries
final_summary = summarizer(combined_summaries, max_length=200, min_length=50, do_sample=False)
print("\nFinal Summary:")
print(final_summary[0]['summary_text'])
# Out:
# Final Summary:
# DO NOT BUY THIS PRODUCT. DO NOT buy this product from "Computer Upgrade King" unless you want to run a game on your NAS. clam-shell cover, no clam shell, no bubble wrap, no plastic

# %% [markdown]
# ---
# <a id="part8"></a>
# ## Part 8. Predictions

# %%
test =["Fantastic Product, Loved it", "Worst product in series", "Could have been better", "Heating issues and delivered late"]
cleaned_test = [cleanText(review) for review in test]
tokenizer = Tokenizer(num_words=top_words)  # Consider using 'num_words' instead of 'nb_words'
print(test)
# If the tokenizer wasn't fit on the entire corpus earlier:
if not tokenizer.word_index:
    tokenizer.fit_on_texts(cleaned_test)  # Fit the tokenizer on the entire corpus for better predictions

# Tokenize the cleaned test reviews
sequences_test = tokenizer.texts_to_sequences(cleaned_test)

# Pad the sequences to a fixed length (same as training data)
padded_test_sequences = sequence.pad_sequences(sequences_test, maxlen=maxlen)

# Make predictions with both models
predictions_model1 = model1.predict(padded_test_sequences)
predictions_model2 = model2.predict(padded_test_sequences)

# Analyze and interpret the predictions based on your models' output formats
# (e.g., probabilities for multiple classes, single class predictions, etc.)
print("Predictions from Model 1:", predictions_model1)
print("Predictions from Model 2:", predictions_model2)
# Out:
# ['Fantastic Product, Loved it', 'Worst product in series', 'Could have been better', 'Heating issues and delivered late']
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Predictions from Model 1: [[1.2462193e-06 9.9999881e-01]
#  [8.4902662e-01 1.5097339e-01]
#  [3.3920469e-07 9.9999964e-01]
#  [9.9184591e-01 8.1541119e-03]]
# Predictions from Model 2: [[4.0744018e-07 9.9999964e-01]
#  [2.1770166e-01 7.8229827e-01]
#  [9.6098290e-08 9.9999988e-01]
#  [9.9511528e-01 4.8847105e-03]]
